# %%
import MGLensing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import MGLensing
#
# ModuleNotFoundError: No module named 'MGLensing'
