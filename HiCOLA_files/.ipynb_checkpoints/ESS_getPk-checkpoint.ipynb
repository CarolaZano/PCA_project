# %%
from configobj import ConfigObj
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline
from scipy.interpolate import RegularGridInterpolator
import pyccl as ccl
from pyDOE2 import *
import matplotlib

#from HiCOLA import Frontend

# %%
def wr_funct(T_CMB):
    return 4.48150052e-7*T_CMB**4 *(1+ 3.044*7/8 * (4/11)**(4/3))

T_CMB = 2.72548 # K
print(wr_funct(T_CMB))

"""Define tracker functions"""

# If we are on the tracker, we will get the following constraints equations

# For today formalism 
def k_1T(Omg_m, Omg_r, f_phi):
    return 6*f_phi*(Omg_m + Omg_r - 1)

# dS formalism

def E_dS(Omg_m, Omg_r, f_phi):

    return np.sqrt((1-f_phi)*(1-Omg_m-Omg_r)/2 + np.sqrt(
        ((1-f_phi)*(1-Omg_m-Omg_r)/2)**2 + f_phi*(1-Omg_m-Omg_r)
    ))
# Out:
# 4.182345109176885e-05

# %%
print(E_dS(sample_new[0], wr_funct(T_CMB)/sample_new[3]**2, 0.42105263157894735))
# Out:
# 0.8758833962962125

# %%
# dimensionless hubble parameter in GR
def E_LCDM_calc(Omg_r,Omg_m, a):
    return np.sqrt(Omg_m/a**3 +Omg_r/a**4 + (1 - Omg_m - Omg_r))

# %%
def T_CMB_funct(wr):
    return (wr/4.48150052e-7/(1+ 3.044*7/8 * (4/11)**(4/3)))**0.25

print(T_CMB_funct(4.28e-5))
# Out:
# 2.7412520861203693

# %%
''' Define useful functions'''

def create_params(f, E, h, omegas):
    '''
    Get parameters k, g from f, E and cosmo
    Inputs:
    f --> fphi
    E --> EdS
    omegas --> [b, c, r] * h^2
    
    Outputs:
    k --> k1dS
    g --> g31dS
    '''
    
    # cosmological constant density
    o_DE = h**2 - omegas[0] - omegas[1] - omegas[2]
    O_L = (1-f)*o_DE/ h**2
    
    # k and g
    alpha = 1 - O_L/E**2
    k = -6*alpha
    g = 2*alpha
    
    return k, g

print(create_params(0.42105263157894735, 1/1.4032496307237814, 0.7307, [0.02196, 0.1274, 4.28e-5]))
# Out:
# (-1.0739300261094205, 0.3579766753698068)

# %%
# We want Omega_m , n_s , A_s ,h,  f_phi, EdS, k_1dS, g_31dS, wr, wb
sample_test = np.array([(0.1274 + 0.02196)/0.7307**2, 0.9626, 2.092e-9,0.7307,0.42105263157894735,1/1.4032496307237814,-0.34384601713152496,-8.289986166458684, 4.28e-5, 0.02196])
print(sample_test)

print("k_2dS test = ",k_2dS_funct(sample_test[4],sample_test[6], sample_test[7],sample_test[5], sample_test[0],4.28e-5/sample_test[3]**2))
print("g_32dS test = ",g_32dS_funct(sample_test[4],sample_test[6], sample_test[7], sample_test[5],sample_test[0],4.28e-5/sample_test[3]**2))

print("k_2dS paper = ", -1.460168017955791)
print("g_32dS paper = ",4.445662089077228)
print("f_phi paper = ", 0.42105263157894735)
print("E_dS paper = ", 1/1.4032496307237814)

k1_dS_new = -0.34384601713152496
g_31_dS_new = -8.289986166458684

sample_new = np.array([0.31966, 0.9626, 2.092e-9,0.6688, 0.3675555555555555,1/1.4032496307237814,k1_dS_new,g_31_dS_new, wr_funct(T_CMB), 0.022383])

k_2_dS_new = k_2dS_funct(sample_new[4],sample_new[6], sample_new[7],sample_test[5], sample_new[0],wr_funct(T_CMB)/sample_new[3]**2)
g_32_dS_new = g_32dS_funct(sample_new[4],sample_new[6], sample_new[7],sample_test[5], sample_new[0],wr_funct(T_CMB)/sample_new[3]**2)

print("k_2dS = ",k_2_dS_new)
print("g_32dS = ",g_32_dS_new)
# Out:
# [ 2.79740979e-01  9.62600000e-01  2.09200000e-09  7.30700000e-01
#   4.21052632e-01  7.12631579e-01 -3.43846017e-01 -8.28998617e+00
#   4.28000000e-05  2.19600000e-02]
# k_2dS test =  -1.460168017955791
# g_32dS test =  4.445662089077228
# k_2dS paper =  -1.460168017955791
# g_32dS paper =  4.445662089077228
# f_phi paper =  0.42105263157894735
# E_dS paper =  0.7126315789473684
# k_2dS =  -1.1465488407358295
# g_32dS =  4.393392226207235

# %%
## Power spectrum from CCL - backscaling

wr = sample_new[-2]

ns = sample_new[1]
As = sample_new[2]
h = sample_new[3]
wm = sample_new[0]*h**2
wb = sample_new[-1]

kk_ccl = np.logspace(-3,1,500)*h               # in 1/Mpc
cosmoLCDM = ccl.Cosmology(Omega_c=(wm - wb)/h**2,
                           Omega_b=wb/h**2, 
                           A_s=As, 
                           h = h,
                           n_s=ns,
                           Omega_k=0)

# Omega_g::: Note that if a non-None value is given, this may result in a physically 
# inconsistent model because the CMB temperature will still be non-zero in the parameters.
cosmoLCDM_norad = ccl.Cosmology(Omega_c=(wm - wb)/h**2,
                           Omega_b=wb/h**2, 
                           A_s=As, 
                           h = h,
                           n_s=ns,
                           Omega_k=0,
                           Omega_g = 0,
                           T_CMB = 0.0)

Pk_0 = ccl.power.linear_matter_power(cosmoLCDM, kk_ccl, 1)    # in (Mpc)^3

Growth_0 = ccl.background.growth_factor(cosmoLCDM_norad, 1)

Growth_49 = ccl.background.growth_factor(cosmoLCDM_norad, 1/(1+49))

Pk_ccl = (Growth_49/Growth_0)**2 * Pk_0*h**3    # in (Mpc)^3/h^3

kk_ccl = kk_ccl/h    # in h/Mpc
## Save power spectrum for initial conditions (Linear)

np.savetxt("/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat", np.array([kk_ccl, Pk_ccl]).T)

# %%
## Plot power spectra (at z = 49, expect very different from z=0)

plt.plot(kk_ccl,Pk_ccl)

plt.xscale("log")
plt.yscale("log")

# %% [markdown]
# ## Get expansion and force files

# %%
''' Define useful functions'''

def Update_ini(run, sample, num_ini, horn_ini):
    """
    Updates file num_ini to include the parameters (numerical)
    """
    h = sample[3]
    wr = sample[-2]
    wb =  sample[-1]
    wc = sample[0]*h**2 - wb
    
    config_n = ConfigObj(num_ini)
    config_h = ConfigObj(horn_ini)
    keys_n = config_n.keys()
    keys_h = config_h.keys()

    k_2_dS_new = k_2dS_funct(sample[4],sample[6], sample[7],sample[5], sample[0],wr/sample[3]**2)
    g_32_dS_new = g_32dS_funct(sample[4],sample[6], sample[7],sample[5], sample[0],wr/sample[3]**2)

    ### Horndeski
    config_h[keys_h[1]] = '/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output'
    config_h[keys_h[0]] = str(run)
    
    config_h[keys_h[2]] = 'k_1*X + k_2*X*X'
    config_h[keys_h[3]] = 'g_31*X + g_32*X*X'
    config_h[keys_h[4]] = '0.5'

    config_h[keys_h[9]] = str(sample[6])
    config_h[keys_h[10]] = str(k_2_dS_new)
    config_h[keys_h[11]] = str(sample[7])
    config_h[keys_h[12]] = str(g_32_dS_new)
    
    config_h[keys_h[13]] = str(sample[4])
    config_h[keys_h[14]] = str(1/sample[5])
    
    ### Numerical
    
    config_n[keys_n[0]] = 'run_'+str(run)
    
    config_n[keys_n[6]] = str(h)
    config_n[keys_n[7]] = str(wr)
    config_n[keys_n[8]] = str(wb)
    config_n[keys_n[9]] = str(wc)
    config_n.filename = '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'
    config_h.filename = '/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini'
    config_n.write()
    config_h.write()

# %%
Update_ini("ESS", sample_new, '/home/c2042999/HiCOLA_env/Cubic_galileon_emu/numerical_parameters.ini', '/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS-C.ini')

# %%
command = 'cd ; cd /home/c2042999/HiCOLA_env/Hi-COLA; python3 -m HiCOLA.Frontend.generate_simulation_input /home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini /home/c2042999/PCA_project/HiCOLA_files/numerical.ini'
#command = 'cd ; cd /home/c2042999/HiCOLA_env/Hi-COLA; python3 -m HiCOLA.Frontend.generate_simulation_input /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/Parameter_files/Frontend_parameter_files/examples/ESS/ESS-C.ini /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/Parameter_files/Frontend_parameter_files/examples/WMAP_cosmological_parameters.ini'

os.system(command)
# Out:
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1465488407358295, -8.289986166458684, 4.393392226207235]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.4302181176364394
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.004674731472211
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# 0

# %%
## Plotting ##

fig, ax = plt.subplots(3,1, figsize=(12,8),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0)

# We want Omega_m*h^2 , n_s    , A_s ,h,  f_phi
expansion_today = np.loadtxt("/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_expansion.txt")

wr = sample_new[-2]
h = sample_new[3]
wm = sample_new[0]*h**2

a_today = expansion_today.T[0]
E_a_today = expansion_today.T[1]
E_a_GR = np.sqrt((wm)*a_today**(-3) + wr*a_today**(-4) + (h**2 - (wm) -wr))/h

ax[0].plot(1/a_today -1, E_a_today/E_a_GR, alpha=0.7)
#ax[0].plot(1/a_today -1, E_a_GR, alpha=0.7)

force_today = np.loadtxt("/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_force.txt")

a_today = force_today.T[0]
chiD_today = force_today.T[1] # chi/delta
coupling = force_today.T[2]

ax[1].plot(1/a_today -1, chiD_today, alpha=0.7)

ax[2].semilogx(1/a_today -1, coupling, alpha=0.7)
#ax[2].semilogx(1/a_today -1, 0.6/E_LCDM_calc(wr/h**2,sample_new[0], a_today)**2, alpha=0.7)

ax[0].set_xscale("log")
ax[2].set_xlabel("z")
ax[0].set_ylabel(r"$E^{CuGal}/E^{\Lambda CDM}$")

ax[1].set_ylabel(r"$\chi/\delta$, CuGal")
ax[2].set_ylabel(r"CuGal coupling $(\beta)$")
# Out:
# Text(0, 0.5, 'CuGal coupling $(\\beta)$')

# %% [markdown]
# ## Find best param combination (only need to do once)

# %%
s_len = 10
f_phi_arange = np.linspace(0.366, 0.3679, s_len)

# %%
print(f_phi_arange[7])
# Out:
# 0.3675555555555555

# %%
sample_new = np.array([np.ones(s_len)*0.31966, np.ones(s_len)*0.9626, np.ones(s_len)*2.092e-9,np.ones(s_len)*0.6688, f_phi_arange,np.ones(s_len)/1.4032496307237814,np.ones(s_len)*k1_dS_new,np.ones(s_len)*g_31_dS_new, np.ones(s_len)*wr_funct(T_CMB), np.ones(s_len)*0.022383])

# %%
for i in range(s_len):
    Update_ini("ESS"+str(i), sample_new.T[i], '/home/c2042999/HiCOLA_env/Cubic_galileon_emu/numerical_parameters.ini', '/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS-C.ini')
    command = 'cd ; cd /home/c2042999/HiCOLA_env/Hi-COLA; python3 -m HiCOLA.Frontend.generate_simulation_input /home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini /home/c2042999/PCA_project/HiCOLA_files/numerical.ini'
    #start = time.time()
    os.system(command)
# Out:
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS0 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1215452167460174, -8.289986166458684, 4.389224955542266]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.43127627885339476
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.0047589420433185
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS1 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1251171630302759, -8.289986166458684, 4.389820279922976]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.4311251129652583
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.004746905383911
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS2 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1286891093145357, -8.289986166458684, 4.390415604303685]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.4309739470771218
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.0047348709181088
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS3 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1322610555987942, -8.289986166458684, 4.391010928684395]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.4308227811889853
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.0047228386453122
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS4 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1358330018830527, -8.289986166458684, 4.391606253065104]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.43067161530084885
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.0047108085649228
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS5 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1394049481673125, -8.289986166458684, 4.392201577445815]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.43052044941271234
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.0046987806763417
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS6 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.142976894451571, -8.289986166458684, 4.392796901826525]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.4303692835245759
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.0046867549789706
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS7 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1465488407358295, -8.289986166458684, 4.393392226207235]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.4302181176364394
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.004674731472211
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS8 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1501207870200894, -8.289986166458684, 4.393987550587944]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.4300669517483029
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.0046627101554657
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS9 model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.1536927333043465, -8.289986166458684, 4.394582874968654]
# Cosmological parameters-----------
# Omega_m0 = 0.31966
# Omega_r0 = 9.350338581260851e-05
# Omega_lambda0 = 0.42991578586016643
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/Frontend/generate_simulation_input.py", line 89, in <module>
#     background_quantities = ns.run_solver(read_out_dict)
#   File "/home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/Frontend/numerical_solver.py", line 266, in run_solver
#     ans = solve_ivp(comp_primes,[x_final,x_ini], Y0, t_eval=x_arr_inv, method='RK45', args=(Hubble0, Omega_r0, Omega_m0, Omega_l0, E_prime_E_lambda, E_prime_E_safelambda, phi_primeprime_lambda, phi_primeprime_safelambda, A_lambda, cl_declaration, parameters,threshold,GR_flag), rtol = 1e-14)#, hmax=hmaxv)
#   File "/home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py", line 591, in solve_ivp
#     message = solver.step()
#   File "/home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py", line 181, in step
#     success, message = self._step_impl()
#   File "/home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py", line 144, in _step_impl
#     y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#   File "/home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/rk.py", line 64, in rk_step
#     K[s] = fun(t + c * h, y + dy)
#   File "/home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py", line 138, in fun
#     return self.fun_single(t, y)
#   File "/home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/base.py", line 20, in fun_wrapped
#     return np.asarray(fun(t, y), dtype=dtype)
#   File "/home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/ivp.py", line 529, in <lambda>
#     fun = lambda t, x, fun=fun: fun(t, x, *args)
#   File "/home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/Frontend/numerical_solver.py", line 176, in comp_primes
#     E_prime_E_evaluated = E_prime_E_lambda(EUY,phi_primeY,Omega_rY,Omega_lY,*parameters)
# KeyboardInterrupt

# %%
## Plotting ##

fig, ax = plt.subplots(3,1, figsize=(12,8),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0)
for i in range(3):
    i=6+i
    # We want Omega_m*h^2 , n_s    , A_s ,h,  f_phi
    expansion_today = np.loadtxt("/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS{}_run_ESS{}_expansion.txt".format(i,i))
    
    wr = sample_new.T[i][-2]
    h = sample_new.T[i][3]
    wm = sample_new.T[i][0]*h**2
    
    a_today = expansion_today.T[0]
    E_a_today = expansion_today.T[1]
    E_a_GR = np.sqrt((wm)*a_today**(-3) + wr*a_today**(-4) + (h**2 - (wm) -wr))/h
    
    ax[0].plot(1/a_today -1, E_a_today/E_a_GR, alpha=0.7)
    #ax[0].plot(1/a_today -1, E_a_GR, alpha=0.7)
    
    force_today = np.loadtxt("/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS{}_run_ESS{}_force.txt".format(i,i))
    
    a_today = force_today.T[0]
    chiD_today = force_today.T[1] # chi/delta
    coupling = force_today.T[2]
    
    ax[1].plot(1/a_today -1, chiD_today, alpha=0.7)
    
    ax[2].semilogx(1/a_today -1, coupling, alpha=0.7)
    #ax[2].semilogx(1/a_today -1, 0.6/E_LCDM_calc(wr/h**2,sample_new[0], a_today)**2, alpha=0.7)
    
    ax[0].set_xscale("log")
    ax[2].set_xlabel("z")
    ax[0].set_ylabel(r"$E^{CuGal}/E^{\Lambda CDM}$")
    
    ax[1].set_ylabel(r"$\chi/\delta$, CuGal")
    ax[2].set_ylabel(r"CuGal coupling $(\beta)$")

# %% [markdown]
# ## Rewrite Lua file

# %%
def rewriteluafile(k, sample,boxsize,n_particles,n_mesh):
    
    #sample = Omega_m , n_s , A_s ,h,  f_phi, EdS, k_1dS, g_31dS, k_2dS, g_32dS, wr, wb

    wb = sample[-1]
    wr = sample[-2]
    n_s = sample[1]
    A_s = sample[2]
    h = sample[3]
    wm = sample[0]*h**2

    f_phi = sample[4]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_ESS-C_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_ESS-C_{}"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB_funct(wr))+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_expansion.txt"'+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_force.txt"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_{}"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(100+k)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = false'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
def rewriteluafile_phasepair(k, sample,boxsize,n_particles,n_mesh):

    #sample = Omega_m , n_s , A_s ,h,  f_phi, EdS, k_1dS, g_31dS, k_2dS, g_32dS, wr, wb

    wb = sample[-1]
    wr = sample[-2]
    n_s = sample[1]
    A_s = sample[2]
    h = sample[3]
    wm = sample[0]*h**2

    f_phi = sample[4]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_ESS-C_phasepair_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_ESS-C_phasepair_{}"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB_funct(wr))+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_expansion.txt"'+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_force.txt"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_{}"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(100+k)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = true'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
## Create lua files

rewriteluafile(8,sample_new,400,512,1536)
# phase pair
rewriteluafile_phasepair(8,sample_new,400,512,1536)

# %%
"""Create P(k)"""

os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_ESS-C_8.lua")
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 80 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-4]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-4]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-4]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-4]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-4]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-4]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-4]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-4]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-4]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-4]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-4]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-4]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-4]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-4]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-4]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-4]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-4]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-4]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-4]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-4]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-4]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-4]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-4]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-4]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-4]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-4]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-4]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-4]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-4]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-4]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-4]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-4]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 62 elements:
# #=====================================================
#   HiCOLA_expansion_filename      : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_expansion.txt
#   HiCOLA_preforce_filename       : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_force.txt
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.092e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.269619
#   cosmology_OmegaLambda          : 0.680246
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.050041
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.6688
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : HiCOLA
#   cosmology_ns                   : 0.9626
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : HiCOLA
#   gravity_model_HiCOLA_smoothing_filter : gaussian
#   gravity_model_HiCOLA_smoothing_scale_over_boxsize : 0.0075
#   gravity_model_screening        : true
#   gravity_model_screening_enforce_largescale_linear : true
#   gravity_model_screening_linear_scale_hmpc : 0.2
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : false
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_8
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_ESS-C_8
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              50 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [HiCOLA]
# # Omegab      : 0.050041
# # OmegaM      : 0.31966
# # OmegaMNu    : 0
# # OmegaCDM    : 0.269619
# # OmegaLambda : 0.680247
# # OmegaR      : 5.52858e-05
# # OmegaNu     : 3.8245e-05
# # OmegaRtot   : 9.35309e-05
# # OmegaK      : 0
# # h           : 0.6688
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 2.092e-09
# # ns          : 0.9626
# # kpivot      : 0.05 1/Mpc
# # HiCOLA_expansion_filename     : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_expansion.txt
# #=====================================================
#
# #=====================================================
# # GravityModel is [HiCOLA] and has the cosmology: [HiCOLA]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# # HiCOLA_preforce_filename : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_force.txt
# # Screening method : true
# # Enforce correct linear evolution : true
# # Scale for which we enforce this  : 0.2 h/Mpc
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_ESS-C_8
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : false
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 50
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_8
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      2.44578         497479
# 0.00251653      5.49082         482322
# 0.00621709      10.8351         438416
# 0.0153593       15.5555         339910
# 0.0379453       10.3036         179007
# 0.0937441       4.03561         72490.7
# 0.231595        0.932724        22550.5
# 0.572157        0.155005        5948.47
# 1.41352         0.0198753       1378.29
# 3.4921          0.00218239      295.531
# 8.62724         0.000215887     60.1453
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 13.9091 (Mpc/h)^3
# k =  0.10: P(k,zini) = 3.58218 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0445885 (Mpc/h)^3
# k = 10.00: P(k,zini) = 0.000146855 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.813299
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.733218 Mpc/h
# Maximum 1LPT velocity: 292.474 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.0102137 Mpc/h
# Maximum 2LPT velocity: 8.16932 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 50
# Step: 0    / 50
# Positions  from z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# Step: 1    / 50
# Positions  from z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# Step: 2    / 50
# Positions  from z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# Step: 3    / 50
# Positions  from z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# Step: 4    / 50
# Positions  from z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# Step: 5    / 50
# Positions  from z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# Step: 6    / 50
# Positions  from z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# Step: 7    / 50
# Positions  from z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# Step: 8    / 50
# Positions  from z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# Step: 9    / 50
# Positions  from z = 4.09165         -> 3.62963
# Velocities from z = 4.35906         -> 3.84966
# Step: 10   / 50
# Positions  from z = 3.62963         -> 3.24448
# Velocities from z = 3.84966         -> 3.4287
# Step: 11   / 50
# Positions  from z = 3.24448         -> 2.9185
# Velocities from z = 3.4287          -> 3.07498
# Step: 12   / 50
# Positions  from z = 2.9185          -> 2.63901
# Velocities from z = 3.07498         -> 2.77358
# Step: 13   / 50
# Positions  from z = 2.63901         -> 2.39674
# Velocities from z = 2.77358         -> 2.5137
# Step: 14   / 50
# Positions  from z = 2.39674         -> 2.18471
# Velocities from z = 2.5137          -> 2.28731
# Step: 15   / 50
# Positions  from z = 2.18471         -> 1.9976
# Velocities from z = 2.28731         -> 2.08833
# Step: 16   / 50
# Positions  from z = 1.9976          -> 1.83126
# Velocities from z = 2.08833         -> 1.91206
# Step: 17   / 50
# Positions  from z = 1.83126         -> 1.6824
# Velocities from z = 1.91206         -> 1.75482
# Step: 18   / 50
# Positions  from z = 1.6824          -> 1.54842
# Velocities from z = 1.75482         -> 1.6137
# Step: 19   / 50
# Positions  from z = 1.54842         -> 1.42718
# Velocities from z = 1.6137          -> 1.48633
# Step: 20   / 50
# Positions  from z = 1.42718         -> 1.31696
# Velocities from z = 1.48633         -> 1.37079
# Step: 21   / 50
# Positions  from z = 1.31696         -> 1.21631
# Velocities from z = 1.37079         -> 1.26552
# Step: 22   / 50
# Positions  from z = 1.21631         -> 1.12404
# Velocities from z = 1.26552         -> 1.1692
# Step: 23   / 50
# Positions  from z = 1.12404         -> 1.03915
# Velocities from z = 1.1692          -> 1.08073
# Step: 24   / 50
# Positions  from z = 1.03915         -> 0.960784
# Velocities from z = 1.08073         -> 0.9992
# Step: 25   / 50
# Positions  from z = 0.960784        -> 0.888218
# Velocities from z = 0.9992          -> 0.923817
# Step: 26   / 50
# Positions  from z = 0.888218        -> 0.82083
# Velocities from z = 0.923817        -> 0.853912
# Step: 27   / 50
# Positions  from z = 0.82083         -> 0.758087
# Velocities from z = 0.853912        -> 0.788909
# Step: 28   / 50
# Positions  from z = 0.758087        -> 0.699524
# Velocities from z = 0.788909        -> 0.72831
# Step: 29   / 50
# Positions  from z = 0.699524        -> 0.644737
# Velocities from z = 0.72831         -> 0.671682
# Step: 30   / 50
# Positions  from z = 0.644737        -> 0.593372
# Velocities from z = 0.671682        -> 0.618647
# Step: 31   / 50
# Positions  from z = 0.593372        -> 0.545117
# Velocities from z = 0.618647        -> 0.568874
# Step: 32   / 50
# Positions  from z = 0.545117        -> 0.4997
# Velocities from z = 0.568874        -> 0.52207
# Step: 33   / 50
# Positions  from z = 0.4997          -> 0.456876
# Velocities from z = 0.52207         -> 0.477978
# Step: 34   / 50
# Positions  from z = 0.456876        -> 0.416431
# Velocities from z = 0.477978        -> 0.436369
# Step: 35   / 50
# Positions  from z = 0.416431        -> 0.37817
# Velocities from z = 0.436369        -> 0.397038
# Step: 36   / 50
# Positions  from z = 0.37817         -> 0.341922
# Velocities from z = 0.397038        -> 0.359804
# Step: 37   / 50
# Positions  from z = 0.341922        -> 0.307531
# Velocities from z = 0.359804        -> 0.324503
# Step: 38   / 50
# Positions  from z = 0.307531        -> 0.27486
# Velocities from z = 0.324503        -> 0.290989
# Step: 39   / 50
# Positions  from z = 0.27486         -> 0.243781
# Velocities from z = 0.290989        -> 0.259129
# Step: 40   / 50
# Positions  from z = 0.243781        -> 0.214182
# Velocities from z = 0.259129        -> 0.228803
# Step: 41   / 50
# Positions  from z = 0.214182        -> 0.185958
# Velocities from z = 0.228803        -> 0.199904
# Step: 42   / 50
# Positions  from z = 0.185958        -> 0.159017
# Velocities from z = 0.199904        -> 0.172333
# Step: 43   / 50
# Positions  from z = 0.159017        -> 0.133273
# Velocities from z = 0.172333        -> 0.146
# Step: 44   / 50
# Positions  from z = 0.133273        -> 0.108647
# Velocities from z = 0.146           -> 0.120825
# Step: 45   / 50
# Positions  from z = 0.108647        -> 0.0850694
# Velocities from z = 0.120825        -> 0.0967317
# Step: 46   / 50
# Positions  from z = 0.0850694       -> 0.0624734
# Velocities from z = 0.0967317       -> 0.0736526
# Step: 47   / 50
# Positions  from z = 0.0624734       -> 0.0407993
# Velocities from z = 0.0736526       -> 0.0515247
# Step: 48   / 50
# Positions  from z = 0.0407993       -> 0.0199918
# Velocities from z = 0.0515247       -> 0.0302905
# Step: 49   / 50
# Positions  from z = 0.0199918       -> 0
# Velocities from z = 0.0302905       -> 0.00989699
# Step: 50   / 50
# Positions  from z = 0               -> 0
# Velocities from z = 0.00989699      -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 50 Total steps taken: 0
# Positions from  z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# deltatime_pos = 7.19326         deltatime_vel = 5.48274
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000533992
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000115019
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4199241 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.6598 %% (min)
# #               50.4309 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4706.21         MB (min over tasks)
# # Current RSS: 4707.11         MB (max over tasks)
# # Peak RSS:    5632.2          MB (min over tasks)
# # Peak RSS:    5633.1          MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 50 Total steps taken: 1
# Positions from  z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# deltatime_pos = 3.22503         deltatime_vel = 4.41367
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00135594
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000192831
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4202725 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5507 %% (min)
# #               50.4872 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4707.75         MB (min over tasks)
# # Current RSS: 4713.9          MB (max over tasks)
# # Peak RSS:    5633.74         MB (min over tasks)
# # Peak RSS:    5634.67         MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 50 Total steps taken: 2
# Positions from  z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# deltatime_pos = 1.93104         deltatime_vel = 2.4069
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000924349
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.0002246
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4208256 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.3842 %% (min)
# #               50.6324 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4687.65         MB (min over tasks)
# # Current RSS: 4715.43         MB (max over tasks)
# # Peak RSS:    5635.4          MB (min over tasks)
# # Peak RSS:    5639.95         MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 50 Total steps taken: 3
# Positions from  z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# deltatime_pos = 1.32061         deltatime_vel = 1.56545
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000750755
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000323509
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4210044 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.2191 %% (min)
# #               50.792 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4688.91         MB (min over tasks)
# # Current RSS: 4716.53         MB (max over tasks)
# # Peak RSS:    5637.04         MB (min over tasks)
# # Peak RSS:    5641.48         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 50 Total steps taken: 4
# Positions from  z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# deltatime_pos = 0.975795        deltatime_vel = 1.12096
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000705531
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000619471
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4211915 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.0723 %% (min)
# #               50.9672 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4690.6          MB (min over tasks)
# # Current RSS: 4718.04         MB (max over tasks)
# # Peak RSS:    5638.49         MB (min over tasks)
# # Peak RSS:    5642.51         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 50 Total steps taken: 5
# Positions from  z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# deltatime_pos = 0.758556        deltatime_vel = 0.852886
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000946445
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000937409
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4214305 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.921 %% (min)
# #               51.1294 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4692.48         MB (min over tasks)
# # Current RSS: 4719.53         MB (max over tasks)
# # Peak RSS:    5640.07         MB (min over tasks)
# # Peak RSS:    5644.1          MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 50 Total steps taken: 6
# Positions from  z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# deltatime_pos = 0.611248        deltatime_vel = 0.676613
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00120041
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00130568
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4216407 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.7786 %% (min)
# #               51.2914 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4693.99         MB (min over tasks)
# # Current RSS: 4721.03         MB (max over tasks)
# # Peak RSS:    5641.5          MB (min over tasks)
# # Peak RSS:    5645.58         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 50 Total steps taken: 7
# Positions from  z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# deltatime_pos = 0.505852        deltatime_vel = 0.553358
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00140787
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00181837
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4218260 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.6367 %% (min)
# #               51.4474 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4695.47         MB (min over tasks)
# # Current RSS: 4722.53         MB (max over tasks)
# # Peak RSS:    5643.04         MB (min over tasks)
# # Peak RSS:    5647.09         MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 50 Total steps taken: 8
# Positions from  z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# deltatime_pos = 0.427336        deltatime_vel = 0.463167
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# ...
#  Time (sec): 831.228       Memory: 943.997       (MB)
#  Time (sec): 831.388       Memory: 1870.05       (MB)
#  Time (sec): 838.419       Memory: 2796.09       (MB)
#  Time (sec): 851.555       Memory: 3722.14       (MB)
#  Time (sec): 852.112       Memory: 4648.19       (MB)
#  Time (sec): 852.578       Memory: 5574.24       (MB)
#  Time (sec): 866.353       Memory: 4648.19       (MB)
#  Time (sec): 868.103       Memory: 3722.14       (MB)
#  Time (sec): 868.402       Memory: 2796.09       (MB)
#  Time (sec): 868.541       Memory: 1870.05       (MB)
#  Time (sec): 868.685       Memory: 943.997       (MB)
#  Time (sec): 868.842       Memory: 1870.05       (MB)
#  Time (sec): 875.745       Memory: 2796.09       (MB)
#  Time (sec): 888.785       Memory: 3722.14       (MB)
#  Time (sec): 889.475       Memory: 4648.19       (MB)
#  Time (sec): 889.949       Memory: 5574.24       (MB)
#  Time (sec): 903.702       Memory: 4648.19       (MB)
#  Time (sec): 905.315       Memory: 3722.14       (MB)
#  Time (sec): 905.563       Memory: 2796.09       (MB)
#  Time (sec): 905.597       Memory: 1870.05       (MB)
#  Time (sec): 905.736       Memory: 943.997       (MB)
#  Time (sec): 905.889       Memory: 1870.05       (MB)
#  Time (sec): 912.942       Memory: 2796.09       (MB)
#  Time (sec): 926.113       Memory: 3722.14       (MB)
#  Time (sec): 926.632       Memory: 4648.19       (MB)
#  Time (sec): 927.106       Memory: 5574.24       (MB)
#  Time (sec): 940.78        Memory: 4648.19       (MB)
#  Time (sec): 942.488       Memory: 3722.14       (MB)
#  Time (sec): 942.765       Memory: 2796.09       (MB)
#  Time (sec): 942.903       Memory: 1870.05       (MB)
#  Time (sec): 943.044       Memory: 943.997       (MB)
#  Time (sec): 943.194       Memory: 1870.05       (MB)
#  Time (sec): 950.126       Memory: 2796.09       (MB)
#  Time (sec): 963.138       Memory: 3722.14       (MB)
#  Time (sec): 963.799       Memory: 4648.19       (MB)
#  Time (sec): 964.265       Memory: 5574.24       (MB)
#  Time (sec): 978.029       Memory: 4648.19       (MB)
#  Time (sec): 979.757       Memory: 3722.14       (MB)
#  Time (sec): 980.026       Memory: 2796.09       (MB)
#  Time (sec): 980.164       Memory: 1870.05       (MB)
#  Time (sec): 980.307       Memory: 943.997       (MB)
#  Time (sec): 980.469       Memory: 1870.05       (MB)
#  Time (sec): 987.401       Memory: 2796.09       (MB)
#  Time (sec): 1000.69       Memory: 3722.14       (MB)
#  Time (sec): 1001.25       Memory: 4648.19       (MB)
#  Time (sec): 1001.72       Memory: 5574.24       (MB)
#  Time (sec): 1015.49       Memory: 4648.19       (MB)
#  Time (sec): 1017.15       Memory: 3722.14       (MB)
#  Time (sec): 1017.43       Memory: 2796.09       (MB)
#  Time (sec): 1017.58       Memory: 1870.05       (MB)
#  Time (sec): 1017.72       Memory: 943.997       (MB)
#  Time (sec): 1017.87       Memory: 1870.05       (MB)
#  Time (sec): 1024.78       Memory: 2796.09       (MB)
#  Time (sec): 1037.9        Memory: 3722.14       (MB)
#  Time (sec): 1038.51       Memory: 4648.19       (MB)
#  Time (sec): 1038.98       Memory: 5574.24       (MB)
#  Time (sec): 1052.8        Memory: 4648.19       (MB)
#  Time (sec): 1054.47       Memory: 3722.14       (MB)
#  Time (sec): 1054.75       Memory: 2796.09       (MB)
#  Time (sec): 1054.89       Memory: 1870.05       (MB)
#  Time (sec): 1055.04       Memory: 943.997       (MB)
#  Time (sec): 1055.19       Memory: 1870.05       (MB)
#  Time (sec): 1062.13       Memory: 2796.09       (MB)
#  Time (sec): 1075.2        Memory: 3722.14       (MB)
#  Time (sec): 1075.93       Memory: 4648.19       (MB)
#  Time (sec): 1076.4        Memory: 5574.24       (MB)
#  Time (sec): 1090.09       Memory: 4648.19       (MB)
#  Time (sec): 1091.85       Memory: 3722.14       (MB)
#  Time (sec): 1092.13       Memory: 2796.09       (MB)
#  Time (sec): 1092.27       Memory: 1870.05       (MB)
#  Time (sec): 1092.41       Memory: 943.997       (MB)
#  Time (sec): 1092.57       Memory: 1870.05       (MB)
#  Time (sec): 1099.48       Memory: 2796.09       (MB)
#  Time (sec): 1112.65       Memory: 3722.14       (MB)
#  Time (sec): 1113.29       Memory: 4648.19       (MB)
#  Time (sec): 1113.76       Memory: 5574.24       (MB)
#  Time (sec): 1127.5        Memory: 4648.19       (MB)
#  Time (sec): 1129.14       Memory: 3722.14       (MB)
memory: 943.997       (MB)
#
# #=====================================================
# 0

# %%
"""Create P(k) phasepair"""

os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_ESS-C_phasepair_8.lua")
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 80 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-4]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-4]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-4]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-4]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-4]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-4]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-4]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-4]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-4]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-4]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-4]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-4]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-4]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-4]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-4]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-4]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-4]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-4]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-4]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-4]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-4]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-4]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-4]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-4]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-4]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-4]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-4]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-4]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-4]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-4]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-4]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-4]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 62 elements:
# #=====================================================
#   HiCOLA_expansion_filename      : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_expansion.txt
#   HiCOLA_preforce_filename       : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_force.txt
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.092e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.269619
#   cosmology_OmegaLambda          : 0.680246
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.050041
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.6688
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : HiCOLA
#   cosmology_ns                   : 0.9626
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : HiCOLA
#   gravity_model_HiCOLA_smoothing_filter : gaussian
#   gravity_model_HiCOLA_smoothing_scale_over_boxsize : 0.0075
#   gravity_model_screening        : true
#   gravity_model_screening_enforce_largescale_linear : true
#   gravity_model_screening_linear_scale_hmpc : 0.2
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : true
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_8
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_ESS-C_phasepair_8
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              50 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [HiCOLA]
# # Omegab      : 0.050041
# # OmegaM      : 0.31966
# # OmegaMNu    : 0
# # OmegaCDM    : 0.269619
# # OmegaLambda : 0.680247
# # OmegaR      : 5.52858e-05
# # OmegaNu     : 3.8245e-05
# # OmegaRtot   : 9.35309e-05
# # OmegaK      : 0
# # h           : 0.6688
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 2.092e-09
# # ns          : 0.9626
# # kpivot      : 0.05 1/Mpc
# # HiCOLA_expansion_filename     : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_expansion.txt
# #=====================================================
#
# #=====================================================
# # GravityModel is [HiCOLA] and has the cosmology: [HiCOLA]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# # HiCOLA_preforce_filename : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS_run_ESS_force.txt
# # Screening method : true
# # Enforce correct linear evolution : true
# # Scale for which we enforce this  : 0.2 h/Mpc
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_ESS-C_phasepair_8
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : true
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 50
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_8
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      2.44578         497479
# 0.00251653      5.49082         482322
# 0.00621709      10.8351         438416
# 0.0153593       15.5555         339910
# 0.0379453       10.3036         179007
# 0.0937441       4.03561         72490.7
# 0.231595        0.932724        22550.5
# 0.572157        0.155005        5948.47
# 1.41352         0.0198753       1378.29
# 3.4921          0.00218239      295.531
# 8.62724         0.000215887     60.1453
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 13.9091 (Mpc/h)^3
# k =  0.10: P(k,zini) = 3.58218 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0445885 (Mpc/h)^3
# k = 10.00: P(k,zini) = 0.000146855 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.813299
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.733218 Mpc/h
# Maximum 1LPT velocity: 292.474 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.0102137 Mpc/h
# Maximum 2LPT velocity: 8.16932 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 50
# Step: 0    / 50
# Positions  from z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# Step: 1    / 50
# Positions  from z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# Step: 2    / 50
# Positions  from z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# Step: 3    / 50
# Positions  from z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# Step: 4    / 50
# Positions  from z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# Step: 5    / 50
# Positions  from z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# Step: 6    / 50
# Positions  from z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# Step: 7    / 50
# Positions  from z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# Step: 8    / 50
# Positions  from z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# Step: 9    / 50
# Positions  from z = 4.09165         -> 3.62963
# Velocities from z = 4.35906         -> 3.84966
# Step: 10   / 50
# Positions  from z = 3.62963         -> 3.24448
# Velocities from z = 3.84966         -> 3.4287
# Step: 11   / 50
# Positions  from z = 3.24448         -> 2.9185
# Velocities from z = 3.4287          -> 3.07498
# Step: 12   / 50
# Positions  from z = 2.9185          -> 2.63901
# Velocities from z = 3.07498         -> 2.77358
# Step: 13   / 50
# Positions  from z = 2.63901         -> 2.39674
# Velocities from z = 2.77358         -> 2.5137
# Step: 14   / 50
# Positions  from z = 2.39674         -> 2.18471
# Velocities from z = 2.5137          -> 2.28731
# Step: 15   / 50
# Positions  from z = 2.18471         -> 1.9976
# Velocities from z = 2.28731         -> 2.08833
# Step: 16   / 50
# Positions  from z = 1.9976          -> 1.83126
# Velocities from z = 2.08833         -> 1.91206
# Step: 17   / 50
# Positions  from z = 1.83126         -> 1.6824
# Velocities from z = 1.91206         -> 1.75482
# Step: 18   / 50
# Positions  from z = 1.6824          -> 1.54842
# Velocities from z = 1.75482         -> 1.6137
# Step: 19   / 50
# Positions  from z = 1.54842         -> 1.42718
# Velocities from z = 1.6137          -> 1.48633
# Step: 20   / 50
# Positions  from z = 1.42718         -> 1.31696
# Velocities from z = 1.48633         -> 1.37079
# Step: 21   / 50
# Positions  from z = 1.31696         -> 1.21631
# Velocities from z = 1.37079         -> 1.26552
# Step: 22   / 50
# Positions  from z = 1.21631         -> 1.12404
# Velocities from z = 1.26552         -> 1.1692
# Step: 23   / 50
# Positions  from z = 1.12404         -> 1.03915
# Velocities from z = 1.1692          -> 1.08073
# Step: 24   / 50
# Positions  from z = 1.03915         -> 0.960784
# Velocities from z = 1.08073         -> 0.9992
# Step: 25   / 50
# Positions  from z = 0.960784        -> 0.888218
# Velocities from z = 0.9992          -> 0.923817
# Step: 26   / 50
# Positions  from z = 0.888218        -> 0.82083
# Velocities from z = 0.923817        -> 0.853912
# Step: 27   / 50
# Positions  from z = 0.82083         -> 0.758087
# Velocities from z = 0.853912        -> 0.788909
# Step: 28   / 50
# Positions  from z = 0.758087        -> 0.699524
# Velocities from z = 0.788909        -> 0.72831
# Step: 29   / 50
# Positions  from z = 0.699524        -> 0.644737
# Velocities from z = 0.72831         -> 0.671682
# Step: 30   / 50
# Positions  from z = 0.644737        -> 0.593372
# Velocities from z = 0.671682        -> 0.618647
# Step: 31   / 50
# Positions  from z = 0.593372        -> 0.545117
# Velocities from z = 0.618647        -> 0.568874
# Step: 32   / 50
# Positions  from z = 0.545117        -> 0.4997
# Velocities from z = 0.568874        -> 0.52207
# Step: 33   / 50
# Positions  from z = 0.4997          -> 0.456876
# Velocities from z = 0.52207         -> 0.477978
# Step: 34   / 50
# Positions  from z = 0.456876        -> 0.416431
# Velocities from z = 0.477978        -> 0.436369
# Step: 35   / 50
# Positions  from z = 0.416431        -> 0.37817
# Velocities from z = 0.436369        -> 0.397038
# Step: 36   / 50
# Positions  from z = 0.37817         -> 0.341922
# Velocities from z = 0.397038        -> 0.359804
# Step: 37   / 50
# Positions  from z = 0.341922        -> 0.307531
# Velocities from z = 0.359804        -> 0.324503
# Step: 38   / 50
# Positions  from z = 0.307531        -> 0.27486
# Velocities from z = 0.324503        -> 0.290989
# Step: 39   / 50
# Positions  from z = 0.27486         -> 0.243781
# Velocities from z = 0.290989        -> 0.259129
# Step: 40   / 50
# Positions  from z = 0.243781        -> 0.214182
# Velocities from z = 0.259129        -> 0.228803
# Step: 41   / 50
# Positions  from z = 0.214182        -> 0.185958
# Velocities from z = 0.228803        -> 0.199904
# Step: 42   / 50
# Positions  from z = 0.185958        -> 0.159017
# Velocities from z = 0.199904        -> 0.172333
# Step: 43   / 50
# Positions  from z = 0.159017        -> 0.133273
# Velocities from z = 0.172333        -> 0.146
# Step: 44   / 50
# Positions  from z = 0.133273        -> 0.108647
# Velocities from z = 0.146           -> 0.120825
# Step: 45   / 50
# Positions  from z = 0.108647        -> 0.0850694
# Velocities from z = 0.120825        -> 0.0967317
# Step: 46   / 50
# Positions  from z = 0.0850694       -> 0.0624734
# Velocities from z = 0.0967317       -> 0.0736526
# Step: 47   / 50
# Positions  from z = 0.0624734       -> 0.0407993
# Velocities from z = 0.0736526       -> 0.0515247
# Step: 48   / 50
# Positions  from z = 0.0407993       -> 0.0199918
# Velocities from z = 0.0515247       -> 0.0302905
# Step: 49   / 50
# Positions  from z = 0.0199918       -> 0
# Velocities from z = 0.0302905       -> 0.00989699
# Step: 50   / 50
# Positions  from z = 0               -> 0
# Velocities from z = 0.00989699      -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 50 Total steps taken: 0
# Positions from  z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# deltatime_pos = 7.19326         deltatime_vel = 5.48274
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# At a= 0.02 chi/delta=0.627019 coupling=0.000376428
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000519727
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000116163
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4189360 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5687 %% (min)
# #               50.3359 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4706.26         MB (min over tasks)
# # Current RSS: 4707.04         MB (max over tasks)
# # Peak RSS:    5631.98         MB (min over tasks)
# # Peak RSS:    5632.76         MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 50 Total steps taken: 1
# Positions from  z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# deltatime_pos = 3.22503         deltatime_vel = 4.41367
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# At a= 0.0396 chi/delta=0.633735 coupling=0.000404315
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00134316
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000206178
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4185104 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5085 %% (min)
# #               50.4635 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4707.79         MB (min over tasks)
# # Current RSS: 4713.77         MB (max over tasks)
# # Peak RSS:    5633.78         MB (min over tasks)
# # Peak RSS:    5634.6          MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 50 Total steps taken: 2
# Positions from  z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# deltatime_pos = 1.93104         deltatime_vel = 2.4069
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# At a= 0.0592 chi/delta=0.636167 coupling=0.000477904
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000923418
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000219775
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4180230 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.3569 %% (min)
# #               50.63 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4686.36         MB (min over tasks)
# # Current RSS: 4715.09         MB (max over tasks)
# # Peak RSS:    5635.37         MB (min over tasks)
# # Peak RSS:    5639.82         MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 50 Total steps taken: 3
# Positions from  z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# deltatime_pos = 1.32061         deltatime_vel = 1.56545
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# At a= 0.0788 chi/delta=0.637172 coupling=0.000619853
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000732481
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000274943
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4177181 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.191 %% (min)
# #               50.8206 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4688.95         MB (min over tasks)
# # Current RSS: 4716.81         MB (max over tasks)
# # Peak RSS:    5636.87         MB (min over tasks)
# # Peak RSS:    5641.14         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 50 Total steps taken: 4
# Positions from  z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# deltatime_pos = 0.975795        deltatime_vel = 1.12096
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# At a= 0.0984 chi/delta=0.637451 coupling=0.000853
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000734013
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000605274
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4174024 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.0103 %% (min)
# #               51.0133 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4690.47         MB (min over tasks)
# # Current RSS: 4718.32         MB (max over tasks)
# # Peak RSS:    5638.39         MB (min over tasks)
# # Peak RSS:    5642.86         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 50 Total steps taken: 5
# Positions from  z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# deltatime_pos = 0.758556        deltatime_vel = 0.852886
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# At a= 0.118 chi/delta=0.63742 coupling=0.00120018
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000755729
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000804321
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4171213 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.8361 %% (min)
# #               51.1825 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4692.17         MB (min over tasks)
# # Current RSS: 4719.82         MB (max over tasks)
# # Peak RSS:    5639.9          MB (min over tasks)
# # Peak RSS:    5644.37         MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 50 Total steps taken: 6
# Positions from  z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# deltatime_pos = 0.611248        deltatime_vel = 0.676613
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# At a= 0.1376 chi/delta=0.63735 coupling=0.00168453
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00101527
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00135935
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4168598 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.6681 %% (min)
# #               51.3517 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4693.88         MB (min over tasks)
# # Current RSS: 4721.33         MB (max over tasks)
# # Peak RSS:    5641.41         MB (min over tasks)
# # Peak RSS:    5645.84         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 50 Total steps taken: 7
# Positions from  z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# deltatime_pos = 0.505852        deltatime_vel = 0.553358
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# At a= 0.1572 chi/delta=0.637425 coupling=0.00232902
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00147518
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00175738
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4166235 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.5099 %% (min)
# #               51.5185 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4695.47         MB (min over tasks)
# # Current RSS: 4722.97         MB (max over tasks)
# # Peak RSS:    5642.92         MB (min over tasks)
# # Peak RSS:    5647.38         MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 50 Total steps taken: 8
# Positions from  z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# deltatime_pos = 0.427336        deltatime_vel = 0.463167
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# At a= 0.1768 chi/delta=0.637734 coupling=0.00315612
# ...
#  Time (sec): 827.616       Memory: 943.997       (MB)
#  Time (sec): 827.759       Memory: 1870.05       (MB)
#  Time (sec): 834.614       Memory: 2796.09       (MB)
#  Time (sec): 847.66        Memory: 3722.14       (MB)
#  Time (sec): 848.249       Memory: 4648.19       (MB)
#  Time (sec): 848.718       Memory: 5574.24       (MB)
#  Time (sec): 862.924       Memory: 4648.19       (MB)
#  Time (sec): 864.567       Memory: 3722.14       (MB)
#  Time (sec): 864.857       Memory: 2796.09       (MB)
#  Time (sec): 864.981       Memory: 1870.05       (MB)
#  Time (sec): 865.121       Memory: 943.997       (MB)
#  Time (sec): 865.273       Memory: 1870.05       (MB)
#  Time (sec): 872.196       Memory: 2796.09       (MB)
#  Time (sec): 885.356       Memory: 3722.14       (MB)
#  Time (sec): 885.935       Memory: 4648.19       (MB)
#  Time (sec): 886.407       Memory: 5574.24       (MB)
#  Time (sec): 900.484       Memory: 4648.19       (MB)
#  Time (sec): 902.209       Memory: 3722.14       (MB)
#  Time (sec): 902.505       Memory: 2796.09       (MB)
#  Time (sec): 902.593       Memory: 1870.05       (MB)
#  Time (sec): 902.738       Memory: 943.997       (MB)
#  Time (sec): 902.887       Memory: 1870.05       (MB)
#  Time (sec): 909.823       Memory: 2796.09       (MB)
#  Time (sec): 923.099       Memory: 3722.14       (MB)
#  Time (sec): 923.599       Memory: 4648.19       (MB)
#  Time (sec): 924.068       Memory: 5574.24       (MB)
#  Time (sec): 938.217       Memory: 4648.19       (MB)
#  Time (sec): 939.766       Memory: 3722.14       (MB)
#  Time (sec): 940.044       Memory: 2796.09       (MB)
#  Time (sec): 940.14        Memory: 1870.05       (MB)
#  Time (sec): 940.282       Memory: 943.997       (MB)
#  Time (sec): 940.433       Memory: 1870.05       (MB)
#  Time (sec): 947.34        Memory: 2796.09       (MB)
#  Time (sec): 960.488       Memory: 3722.14       (MB)
#  Time (sec): 961.028       Memory: 4648.19       (MB)
#  Time (sec): 961.497       Memory: 5574.24       (MB)
#  Time (sec): 975.666       Memory: 4648.19       (MB)
#  Time (sec): 977.303       Memory: 3722.14       (MB)
#  Time (sec): 977.594       Memory: 2796.09       (MB)
#  Time (sec): 977.698       Memory: 1870.05       (MB)
#  Time (sec): 977.839       Memory: 943.997       (MB)
#  Time (sec): 978.004       Memory: 1870.05       (MB)
#  Time (sec): 984.885       Memory: 2796.09       (MB)
#  Time (sec): 997.915       Memory: 3722.14       (MB)
#  Time (sec): 998.483       Memory: 4648.19       (MB)
#  Time (sec): 998.955       Memory: 5574.24       (MB)
#  Time (sec): 1013.03       Memory: 4648.19       (MB)
#  Time (sec): 1804.03       Memory: 2796.09       (MB)
#  Time (sec): 1804.06       Memory: 1870.05       (MB)
#  Time (sec): 1804.15       Memory: 943.997       (MB)
#  Time (sec): 1804.31       Memory: 1870.05       (MB)
#  Time (sec): 1811.38       Memory: 2796.09       (MB)
#  Time (sec): 1824.44       Memory: 3722.14       (MB)
#  Time (sec): 1825.05       Memory: 4648.19       (MB)
#  Time (sec): 1825.52       Memory: 5574.24       (MB)
#  Time (sec): 1839.5        Memory: 4648.19       (MB)
#  Time (sec): 1841.42       Memory: 3722.14       (MB)
#  Time (sec): 1841.68       Memory: 2796.09       (MB)
#  Time (sec): 1841.77       Memory: 1870.05       (MB)
#  Time (sec): 1841.91       Memory: 943.997       (MB)
#  Time (sec): 1842.07       Memory: 1870.05       (MB)
#  Time (sec): 1849.04       Memory: 2796.09       (MB)
#  Time (sec): 1862.17       Memory: 3722.14       (MB)
#  Time (sec): 1862.71       Memory: 4648.19       (MB)
#  Time (sec): 1863.18       Memory: 5574.24       (MB)
#  Time (sec): 1877.29       Memory: 4648.19       (MB)
#  Time (sec): 1878.95       Memory: 3722.14       (MB)
#  Time (sec): 1879.26       Memory: 2796.09       (MB)
#  Time (sec): 1879.4        Memory: 1870.05       (MB)
#  Time (sec): 1879.54       Memory: 943.997       (MB)
#  Time (sec): 1879.67       Memory: 1870.05       (MB)
#  Time (sec): 1886.56       Memory: 2796.09       (MB)
#  Time (sec): 1899.81       Memory: 3722.14       (MB)
#  Time (sec): 1900.37       Memory: 4648.19       (MB)
#  Time (sec): 1900.84       Memory: 5574.24       (MB)
#  Time (sec): 1914.95       Memory: 4648.19       (MB)
#  Time (sec): 1916.31       Memory: 3722.14       (MB)
#  Time (sec): 1916.63       Memory: 2796.09       (MB)
#  Time (sec): 1916.77       Memory: 1870.05       (MB)
#  Time (sec): 1916.89       Memory: 943.997       (MB)
#  Time (sec): 1917.92       Memory: 1926.74       (MB)
#  Time (sec): 1922.64       Memory: 2909.49       (MB)
#  Time (sec): 1936.47       Memory: 1926.74       (MB)
#  Time (sec): 1938.07       Memory: 943.997       (MB)
#
# #=====================================================
# 0

# %%
def rewriteluafile_GR(k, sample,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    #sample = Omega_m , n_s , A_s ,h,  f_phi, EdS, k_1dS, g_31dS, k_2dS, g_32dS, wr, wb

    wb = sample[-1]
    wr = sample[-2]
    n_s = sample[1]
    A_s = sample[2]
    h = sample[3]
    wm = sample[0]*h**2

    f_phi = sample[4]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_GR_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_GR_{}"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "None"'+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "None"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_{}"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = false'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
def rewriteluafile_GR_phasepair(k, sample,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    #sample = Omega_m , n_s , A_s ,h,  f_phi, EdS, k_1dS, g_31dS, k_2dS, g_32dS, wr, wb

    wb = sample[-1]
    wr = sample[-2]
    n_s = sample[1]
    A_s = sample[2]
    h = sample[3]
    wm = sample[0]*h**2

    f_phi = sample[4]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_GR_phasepair_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_GR_phasepair_{}"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "None"'+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "None"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_{}"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = true'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
## Create GR lua files

rewriteluafile_GR(8,sample_new,400,512,1536)
# phase pair
rewriteluafile_GR_phasepair(8,sample_new,400,512,1536)

# %%
"""Create P(k) GR"""

os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_GR_8.lua")
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 80 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-4]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-4]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-4]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-4]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-4]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-4]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-4]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-4]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-4]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-4]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-4]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-4]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-4]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-4]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-4]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-4]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-4]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-4]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-4]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-4]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-4]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-4]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-4]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-4]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-4]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-4]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-4]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-4]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-4]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-4]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-4]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-4]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 55 elements:
# #=====================================================
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.092e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.269619
#   cosmology_OmegaLambda          : 0.680246
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.050041
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.6688
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : LCDM
#   cosmology_ns                   : 0.9626
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : GR
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : false
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_8
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_GR_8
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              50 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [LCDM]
# # Omegab      : 0.050041
# # OmegaM      : 0.31966
# # OmegaMNu    : 0
# # OmegaCDM    : 0.269619
# # OmegaLambda : 0.680247
# # OmegaR      : 5.52858e-05
# # OmegaNu     : 3.8245e-05
# # OmegaRtot   : 9.35309e-05
# # OmegaK      : 0
# # h           : 0.6688
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 2.092e-09
# # ns          : 0.9626
# # kpivot      : 0.05 1/Mpc
# #=====================================================
#
# #=====================================================
# # GravityModel is [GR] and has the cosmology: [LCDM]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_GR_8
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : false
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 50
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_8
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      2.44578         497479
# 0.00251653      5.49082         482322
# 0.00621709      10.8351         438416
# 0.0153593       15.5555         339910
# 0.0379453       10.3036         179007
# 0.0937441       4.03561         72490.7
# 0.231595        0.932724        22550.5
# 0.572157        0.155005        5948.47
# 1.41352         0.0198753       1378.29
# 3.4921          0.00218239      295.531
# 8.62724         0.000215887     60.1453
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 13.9091 (Mpc/h)^3
# k =  0.10: P(k,zini) = 3.58218 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0445885 (Mpc/h)^3
# k = 10.00: P(k,zini) = 0.000146855 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.814216
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.733218 Mpc/h
# Maximum 1LPT velocity: 292.516 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.0102137 Mpc/h
# Maximum 2LPT velocity: 8.17004 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 50
# Step: 0    / 50
# Positions  from z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# Step: 1    / 50
# Positions  from z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# Step: 2    / 50
# Positions  from z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# Step: 3    / 50
# Positions  from z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# Step: 4    / 50
# Positions  from z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# Step: 5    / 50
# Positions  from z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# Step: 6    / 50
# Positions  from z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# Step: 7    / 50
# Positions  from z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# Step: 8    / 50
# Positions  from z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# Step: 9    / 50
# Positions  from z = 4.09165         -> 3.62963
# Velocities from z = 4.35906         -> 3.84966
# Step: 10   / 50
# Positions  from z = 3.62963         -> 3.24448
# Velocities from z = 3.84966         -> 3.4287
# Step: 11   / 50
# Positions  from z = 3.24448         -> 2.9185
# Velocities from z = 3.4287          -> 3.07498
# Step: 12   / 50
# Positions  from z = 2.9185          -> 2.63901
# Velocities from z = 3.07498         -> 2.77358
# Step: 13   / 50
# Positions  from z = 2.63901         -> 2.39674
# Velocities from z = 2.77358         -> 2.5137
# Step: 14   / 50
# Positions  from z = 2.39674         -> 2.18471
# Velocities from z = 2.5137          -> 2.28731
# Step: 15   / 50
# Positions  from z = 2.18471         -> 1.9976
# Velocities from z = 2.28731         -> 2.08833
# Step: 16   / 50
# Positions  from z = 1.9976          -> 1.83126
# Velocities from z = 2.08833         -> 1.91206
# Step: 17   / 50
# Positions  from z = 1.83126         -> 1.6824
# Velocities from z = 1.91206         -> 1.75482
# Step: 18   / 50
# Positions  from z = 1.6824          -> 1.54842
# Velocities from z = 1.75482         -> 1.6137
# Step: 19   / 50
# Positions  from z = 1.54842         -> 1.42718
# Velocities from z = 1.6137          -> 1.48633
# Step: 20   / 50
# Positions  from z = 1.42718         -> 1.31696
# Velocities from z = 1.48633         -> 1.37079
# Step: 21   / 50
# Positions  from z = 1.31696         -> 1.21631
# Velocities from z = 1.37079         -> 1.26552
# Step: 22   / 50
# Positions  from z = 1.21631         -> 1.12404
# Velocities from z = 1.26552         -> 1.1692
# Step: 23   / 50
# Positions  from z = 1.12404         -> 1.03915
# Velocities from z = 1.1692          -> 1.08073
# Step: 24   / 50
# Positions  from z = 1.03915         -> 0.960784
# Velocities from z = 1.08073         -> 0.9992
# Step: 25   / 50
# Positions  from z = 0.960784        -> 0.888218
# Velocities from z = 0.9992          -> 0.923817
# Step: 26   / 50
# Positions  from z = 0.888218        -> 0.82083
# Velocities from z = 0.923817        -> 0.853912
# Step: 27   / 50
# Positions  from z = 0.82083         -> 0.758087
# Velocities from z = 0.853912        -> 0.788909
# Step: 28   / 50
# Positions  from z = 0.758087        -> 0.699524
# Velocities from z = 0.788909        -> 0.72831
# Step: 29   / 50
# Positions  from z = 0.699524        -> 0.644737
# Velocities from z = 0.72831         -> 0.671682
# Step: 30   / 50
# Positions  from z = 0.644737        -> 0.593372
# Velocities from z = 0.671682        -> 0.618647
# Step: 31   / 50
# Positions  from z = 0.593372        -> 0.545117
# Velocities from z = 0.618647        -> 0.568874
# Step: 32   / 50
# Positions  from z = 0.545117        -> 0.4997
# Velocities from z = 0.568874        -> 0.52207
# Step: 33   / 50
# Positions  from z = 0.4997          -> 0.456876
# Velocities from z = 0.52207         -> 0.477978
# Step: 34   / 50
# Positions  from z = 0.456876        -> 0.416431
# Velocities from z = 0.477978        -> 0.436369
# Step: 35   / 50
# Positions  from z = 0.416431        -> 0.37817
# Velocities from z = 0.436369        -> 0.397038
# Step: 36   / 50
# Positions  from z = 0.37817         -> 0.341922
# Velocities from z = 0.397038        -> 0.359804
# Step: 37   / 50
# Positions  from z = 0.341922        -> 0.307531
# Velocities from z = 0.359804        -> 0.324503
# Step: 38   / 50
# Positions  from z = 0.307531        -> 0.27486
# Velocities from z = 0.324503        -> 0.290989
# Step: 39   / 50
# Positions  from z = 0.27486         -> 0.243781
# Velocities from z = 0.290989        -> 0.259129
# Step: 40   / 50
# Positions  from z = 0.243781        -> 0.214182
# Velocities from z = 0.259129        -> 0.228803
# Step: 41   / 50
# Positions  from z = 0.214182        -> 0.185958
# Velocities from z = 0.228803        -> 0.199904
# Step: 42   / 50
# Positions  from z = 0.185958        -> 0.159017
# Velocities from z = 0.199904        -> 0.172333
# Step: 43   / 50
# Positions  from z = 0.159017        -> 0.133273
# Velocities from z = 0.172333        -> 0.146
# Step: 44   / 50
# Positions  from z = 0.133273        -> 0.108647
# Velocities from z = 0.146           -> 0.120825
# Step: 45   / 50
# Positions  from z = 0.108647        -> 0.0850694
# Velocities from z = 0.120825        -> 0.0967317
# Step: 46   / 50
# Positions  from z = 0.0850694       -> 0.0624734
# Velocities from z = 0.0967317       -> 0.0736526
# Step: 47   / 50
# Positions  from z = 0.0624734       -> 0.0407993
# Velocities from z = 0.0736526       -> 0.0515247
# Step: 48   / 50
# Positions  from z = 0.0407993       -> 0.0199918
# Velocities from z = 0.0515247       -> 0.0302905
# Step: 49   / 50
# Positions  from z = 0.0199918       -> 0
# Velocities from z = 0.0302905       -> 0.00989699
# Step: 50   / 50
# Positions  from z = 0               -> 0
# Velocities from z = 0.00989699      -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 50 Total steps taken: 0
# Positions from  z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# deltatime_pos = 7.19816         deltatime_vel = 5.48645
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.000534544
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000115156
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4199245 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.6597 %% (min)
# #               50.4309 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4706.07         MB (min over tasks)
# # Current RSS: 4706.78         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4808.32         MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 50 Total steps taken: 1
# Positions from  z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# deltatime_pos = 3.22722         deltatime_vel = 4.41666
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00135777
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000193153
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4202733 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5505 %% (min)
# #               50.4875 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4707.59         MB (min over tasks)
# # Current RSS: 4713.59         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4809.83         MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 50 Total steps taken: 2
# Positions from  z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# deltatime_pos = 1.93234         deltatime_vel = 2.40852
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.000926788
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000225041
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4208252 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.384 %% (min)
# #               50.6331 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4687.18         MB (min over tasks)
# # Current RSS: 4715.04         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4814.24         MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 50 Total steps taken: 3
# Positions from  z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# deltatime_pos = 1.32148         deltatime_vel = 1.5665
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.000752821
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000323632
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4210073 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.2181 %% (min)
# #               50.793 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4688.92         MB (min over tasks)
# # Current RSS: 4716.64         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4815.29         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 50 Total steps taken: 4
# Positions from  z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# deltatime_pos = 0.976417        deltatime_vel = 1.12169
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.000703404
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000618394
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4211937 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.0715 %% (min)
# #               50.9677 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4690.63         MB (min over tasks)
# # Current RSS: 4718.14         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4815.29         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 50 Total steps taken: 5
# Positions from  z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# deltatime_pos = 0.759032        deltatime_vel = 0.853426
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00093926
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000940402
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4214345 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.9198 %% (min)
# #               51.1305 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4692.42         MB (min over tasks)
# # Current RSS: 4719.64         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4816.97         MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 50 Total steps taken: 6
# Positions from  z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# deltatime_pos = 0.6116          deltatime_vel = 0.677013
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00121856
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00131218
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4216373 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.7774 %% (min)
# #               51.2926 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4694.11         MB (min over tasks)
# # Current RSS: 4721.13         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4818.68         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 50 Total steps taken: 7
# Positions from  z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# deltatime_pos = 0.506125        deltatime_vel = 0.553671
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.0014078
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00181732
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4218348 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.6356 %% (min)
# #               51.449 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4695.66         MB (min over tasks)
# # Current RSS: 4722.63         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4820.64         MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 50 Total steps taken: 8
# Positions from  z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# deltatime_pos = 0.427543        deltatime_vel = 0.463402
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00154141
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00216135
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4221560 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.5037 %% (min)
# #               51.6203 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4696.82         MB (min over tasks)
# # Current RSS: 4724            MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4822.47         MB (max over tasks)
# #=====================================================
#
# Taking substep: 9 / 50 Total steps taken: 9
# Positions from  z = 4.09165         -> 3.62963
# Velocities from z = 4.35906         -> 3.84966
# deltatime_pos = 0.367097        deltatime_vel = 0.394948
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00205786
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00289891
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4224391 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.3781 %% (min)
# #               51.7999 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4698.42         MB (min over tasks)
# # Current RSS: 4725.51         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4824.33         MB (max over tasks)
# #=====================================================
#
# Taking substep: 10 / 50 Total steps taken: 10
# Positions from  z = 3.62963         -> 3.24448
# Velocities from z = 3.84966         -> 3.4287
# deltatime_pos = 0.319383        deltatime_vel = 0.341541
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.0019453
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00287257
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4227361 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.2492 %% (min)
# #               51.9695 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4699.85         MB (min over tasks)
# # Current RSS: 4727.01         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4826.19         MB (max over tasks)
# #=====================================================
#
# Taking substep: 11 / 50 Total steps taken: 11
# Positions from  z = 3.24448         -> 2.9185
# Velocities from z = 3.4287          -> 3.07498
# deltatime_pos = 0.280908        deltatime_vel = 0.298893
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00177004
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00298237
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4230653 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.1283 %% (min)
# #               52.1341 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4701.44         MB (min over tasks)
# # Current RSS: 4728.53         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4828.05         MB (max over tasks)
# #=====================================================
#
# Taking substep: 12 / 50 Total steps taken: 12
# Positions from  z = 2.9185          -> 2.63901
# Velocities from z = 3.07498         -> 2.77358
# deltatime_pos = 0.24932         deltatime_vel = 0.264167
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00170523
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00307768
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4233695 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.0169 %% (min)
# #               52.3054 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4703.15         MB (min over tasks)
# # Current RSS: 4730.04         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4829.86         MB (max over tasks)
# #=====================================================
#
# Taking substep: 13 / 50 Total steps taken: 13
# Positions from  z = 2.63901         -> 2.39674
# Velocities from z = 2.77358         -> 2.5137
# deltatime_pos = 0.222986        deltatime_vel = 0.235422
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00189743
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00332887
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4237003 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.9129 %% (min)
# #               52.4757 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4704.68         MB (min over tasks)
# # Current RSS: 4731.54         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4831.75         MB (max over tasks)
# #=====================================================
#
# Taking substep: 14 / 50 Total steps taken: 14
# Positions from  z = 2.39674         -> 2.18471
# Velocities from z = 2.5137          -> 2.28731
# deltatime_pos = 0.200739        deltatime_vel = 0.211288
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00195451
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00333481
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4240237 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.8148 %% (min)
# #               52.6433 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4706.16         MB (min over tasks)
# # Current RSS: 4733.05         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4833.61         MB (max over tasks)
# #=====================================================
#
# Taking substep: 15 / 50 Total steps taken: 15
# Positions from  z = 2.18471         -> 1.9976
# Velocities from z = 2.28731         -> 2.08833
# deltatime_pos = 0.181729        deltatime_vel = 0.190775
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00182757
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00373026
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4243023 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.7185 %% (min)
# #               52.8106 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4707.73         MB (min over tasks)
# # Current RSS: 4734.56         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4835.46         MB (max over tasks)
# #=====================================================
#
# Taking substep: 16 / 50 Total steps taken: 16
# Positions from  z = 1.9976          -> 1.83126
# Velocities from z = 2.08833         -> 1.91206
# deltatime_pos = 0.165319        deltatime_vel = 0.173152
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.0017248
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00337855
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4245829 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.6209 %% (min)
# #               52.971 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4709.17         MB (min over tasks)
# # Current RSS: 4736.08         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4837.17         MB (max over tasks)
# #=====================================================
#
# Taking substep: 17 / 50 Total steps taken: 17
# Positions from  z = 1.83126         -> 1.6824
# Velocities from z = 1.91206         -> 1.75482
# deltatime_pos = 0.151026        deltatime_vel = 0.157867
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00216962
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00388776
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4249839 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.5313 %% (min)
# #               53.136 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4710.5          MB (min over tasks)
# # Current RSS: 4737.59         MB (max over tasks)
# # Peak RSS:    4806.51         MB (min over tasks)
# # Peak RSS:    4839.14         MB (max over tasks)
# #=====================================================
#
# Taking substep: 18 / 50 Total steps taken: 18
# Positions from  z = 1.6824          -> 1.54842
# Velocities from z = 1.75482         -> 1.6137
# deltatime_pos = 0.138479        deltatime_vel = 0.144499
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00200298
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00419521
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4253505 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.4441 %% (min)
# #               53.3064 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4712.17         MB (min over tasks)
# # Current RSS: 4739.1          MB (max over tasks)
# ...
#  Time (sec): 336.173       Memory: 2796.09       (MB)
#  Time (sec): 336.313       Memory: 1870.05       (MB)
#  Time (sec): 336.453       Memory: 943.997       (MB)
#  Time (sec): 336.612       Memory: 1870.05       (MB)
#  Time (sec): 343.364       Memory: 2796.09       (MB)
#  Time (sec): 343.945       Memory: 3722.14       (MB)
#  Time (sec): 344.45        Memory: 4648.19       (MB)
#  Time (sec): 358.177       Memory: 3722.14       (MB)
#  Time (sec): 358.331       Memory: 2796.09       (MB)
#  Time (sec): 358.476       Memory: 1870.05       (MB)
#  Time (sec): 358.619       Memory: 943.997       (MB)
#  Time (sec): 358.779       Memory: 1870.05       (MB)
#  Time (sec): 365.546       Memory: 2796.09       (MB)
#  Time (sec): 366.014       Memory: 3722.14       (MB)
#  Time (sec): 366.48        Memory: 4648.19       (MB)
#  Time (sec): 380.299       Memory: 3722.14       (MB)
#  Time (sec): 380.447       Memory: 2796.09       (MB)
#  Time (sec): 380.591       Memory: 1870.05       (MB)
#  Time (sec): 380.734       Memory: 943.997       (MB)
#  Time (sec): 380.895       Memory: 1870.05       (MB)
#  Time (sec): 387.685       Memory: 2796.09       (MB)
#  Time (sec): 388.151       Memory: 3722.14       (MB)
#  Time (sec): 388.613       Memory: 4648.19       (MB)
#  Time (sec): 402.366       Memory: 3722.14       (MB)
#  Time (sec): 402.511       Memory: 2796.09       (MB)
#  Time (sec): 402.652       Memory: 1870.05       (MB)
#  Time (sec): 402.792       Memory: 943.997       (MB)
#  Time (sec): 402.952       Memory: 1870.05       (MB)
#  Time (sec): 409.724       Memory: 2796.09       (MB)
#  Time (sec): 410.2         Memory: 3722.14       (MB)
#  Time (sec): 410.669       Memory: 4648.19       (MB)
#  Time (sec): 424.502       Memory: 3722.14       (MB)
#  Time (sec): 424.656       Memory: 2796.09       (MB)
#  Time (sec): 424.802       Memory: 1870.05       (MB)
#  Time (sec): 424.943       Memory: 943.997       (MB)
#  Time (sec): 425.102       Memory: 1870.05       (MB)
#  Time (sec): 431.898       Memory: 2796.09       (MB)
#  Time (sec): 432.372       Memory: 3722.14       (MB)
#  Time (sec): 432.896       Memory: 4648.19       (MB)
#  Time (sec): 446.617       Memory: 3722.14       (MB)
#  Time (sec): 446.779       Memory: 2796.09       (MB)
#  Time (sec): 446.937       Memory: 1870.05       (MB)
#  Time (sec): 447.081       Memory: 943.997       (MB)
#  Time (sec): 447.223       Memory: 1870.05       (MB)
#  Time (sec): 454.022       Memory: 2796.09       (MB)
#  Time (sec): 454.547       Memory: 3722.14       (MB)
#  Time (sec): 454.987       Memory: 4648.19       (MB)
#  Time (sec): 468.765       Memory: 3722.14       (MB)
#  Time (sec): 468.943       Memory: 2796.09       (MB)
#  Time (sec): 469.119       Memory: 1870.05       (MB)
#  Time (sec): 469.262       Memory: 943.997       (MB)
#  Time (sec): 469.41        Memory: 1870.05       (MB)
#  Time (sec): 476.202       Memory: 2796.09       (MB)
#  Time (sec): 476.667       Memory: 3722.14       (MB)
#  Time (sec): 477.13        Memory: 4648.19       (MB)
#  Time (sec): 490.927       Memory: 3722.14       (MB)
#  Time (sec): 491.072       Memory: 2796.09       (MB)
#  Time (sec): 491.221       Memory: 1870.05       (MB)
#  Time (sec): 491.363       Memory: 943.997       (MB)
#  Time (sec): 491.524       Memory: 1870.05       (MB)
#  Time (sec): 498.29        Memory: 2796.09       (MB)
#  Time (sec): 498.763       Memory: 3722.14       (MB)
#  Time (sec): 499.231       Memory: 4648.19       (MB)
#  Time (sec): 513.021       Memory: 3722.14       (MB)
#  Time (sec): 513.172       Memory: 2796.09       (MB)
#  Time (sec): 513.312       Memory: 1870.05       (MB)
#  Time (sec): 513.453       Memory: 943.997       (MB)
#  Time (sec): 513.621       Memory: 1870.05       (MB)
#  Time (sec): 520.397       Memory: 2796.09       (MB)
#  Time (sec): 520.876       Memory: 3722.14       (MB)
#  Time (sec): 521.405       Memory: 4648.19       (MB)
#  Time (sec): 535.134       Memory: 3722.14       (MB)
#  Time (sec): 535.272       Memory: 2796.09       (MB)
#  Time (sec): 535.41        Memory: 1870.05       (MB)
#  Time (sec): 535.552       Memory: 943.997       (MB)
#  Time (sec): 535.713       Memory: 1870.05       (MB)
#  Time (sec): 542.574       Memory: 2796.09       (MB)
#  Time (sec): 543.04        Memory: 3722.14       (MB)
#  Time (sec): 543.507       Memory: 4648.19       (MB)
#  Time (sec): 557.352       Memory: 3722.14       (MB)
#  Time (sec): 557.523       Memory: 2796.09       (MB)
#  Time (sec): 557.692       Memory: 1870.05       (MB)
#  Time (sec): 557.837       Memory: 943.997       (MB)
#  Time (sec): 557.981       Memory: 1870.05       (MB)
#  Time (sec): 564.819       Memory: 2796.09       (MB)
#  Time (sec): 565.279       Memory: 3722.14       (MB)
#  Time (sec): 565.743       Memory: 4648.19       (MB)
#  Time (sec): 579.635       Memory: 3722.14       (MB)
#  Time (sec): 579.798       Memory: 2796.09       (MB)
#  Time (sec): 579.942       Memory: 1870.05       (MB)
#  Time (sec): 580.084       Memory: 943.997       (MB)
#  Time (sec): 580.232       Memory: 1870.05       (MB)
#  Time (sec): 587.014       Memory: 2796.09       (MB)
#  Time (sec): 587.487       Memory: 3722.14       (MB)
#  Time (sec): 587.958       Memory: 4648.19       (MB)
#  Time (sec): 601.773       Memory: 3722.14       (MB)
#  Time (sec): 601.916       Memory: 2796.09       (MB)
#  Time (sec): 602.056       Memory: 1870.05       (MB)
#  Time (sec): 602.197       Memory: 943.997       (MB)
#  Time (sec): 602.361       Memory: 1870.05       (MB)
#  Time (sec): 609.17        Memory: 2796.09       (MB)
#  Time (sec): 609.643       Memory: 3722.14       (MB)
#  Time (sec): 610.111       Memory: 4648.19       (MB)
#  Time (sec): 623.868       Memory: 3722.14       (MB)
#  Time (sec): 624.028       Memory: 2796.09       (MB)
#  Time (sec): 624.192       Memory: 1870.05       (MB)
#  Time (sec): 624.342       Memory: 943.997       (MB)
#  Time (sec): 624.5         Memory: 1870.05       (MB)
#  Time (sec): 631.252       Memory: 2796.09       (MB)
#  Time (sec): 631.722       Memory: 3722.14       (MB)
#  Time (sec): 632.188       Memory: 4648.19       (MB)
#  Time (sec): 646.105       Memory: 3722.14       (MB)
#  Time (sec): 646.26        Memory: 2796.09       (MB)
#  Time (sec): 646.406       Memory: 1870.05       (MB)
#  Time (sec): 646.548       Memory: 943.997       (MB)
#  Time (sec): 646.708       Memory: 1870.05       (MB)
#  Time (sec): 653.482       Memory: 2796.09       (MB)
#  Time (sec): 653.952       Memory: 3722.14       (MB)
#  Time (sec): 654.415       Memory: 4648.19       (MB)
#  Time (sec): 668.195       Memory: 3722.14       (MB)
#  Time (sec): 668.341       Memory: 2796.09       (MB)
#  Time (sec): 668.491       Memory: 1870.05       (MB)
#  Time (sec): 668.633       Memory: 943.997       (MB)
#  Time (sec): 668.792       Memory: 1870.05       (MB)
#  Time (sec): 675.581       Memory: 2796.09       (MB)
#  Time (sec): 676.116       Memory: 3722.14       (MB)
#  Time (sec): 676.563       Memory: 4648.19       (MB)
#  Time (sec): 690.307       Memory: 3722.14       (MB)
#  Time (sec): 690.453       Memory: 2796.09       (MB)
#  Time (sec): 690.596       Memory: 1870.05       (MB)
#  Time (sec): 690.742       Memory: 943.997       (MB)
#  Time (sec): 690.906       Memory: 1870.05       (MB)
#  Time (sec): 697.75        Memory: 2796.09       (MB)
#  Time (sec): 698.221       Memory: 3722.14       (MB)
#  Time (sec): 698.686       Memory: 4648.19       (MB)
#  Time (sec): 712.477       Memory: 3722.14       (MB)
#  Time (sec): 712.629       Memory: 2796.09       (MB)
#  Time (sec): 712.775       Memory: 1870.05       (MB)
#  Time (sec): 712.917       Memory: 943.997       (MB)
#  Time (sec): 713.076       Memory: 1870.05       (MB)
#  Time (sec): 719.919       Memory: 2796.09       (MB)
#  Time (sec): 720.388       Memory: 3722.14       (MB)
#  Time (sec): 720.854       Memory: 4648.19       (MB)
#  Time (sec): 734.641       Memory: 3722.14       (MB)
#  Time (sec): 734.788       Memory: 2796.09       (MB)
#  Time (sec): 734.929       Memory: 1870.05       (MB)
#  Time (sec): 735.072       Memory: 943.997       (MB)
#  Time (sec): 735.231       Memory: 1870.05       (MB)
#  Time (sec): 742.046       Memory: 2796.09       (MB)
#  Time (sec): 742.514       Memory: 3722.14       (MB)
#  Time (sec): 742.978       Memory: 4648.19       (MB)
#  Time (sec): 756.788       Memory: 3722.14       (MB)
#  Time (sec): 756.934       Memory: 2796.09       (MB)
#  Time (sec): 757.087       Memory: 1870.05       (MB)
#  Time (sec): 757.24        Memory: 943.997       (MB)
#  Time (sec): 757.394       Memory: 1870.05       (MB)
#  Time (sec): 764.213       Memory: 2796.09       (MB)
#  Time (sec): 764.68        Memory: 3722.14       (MB)
#  Time (sec): 765.145       Memory: 4648.19       (MB)
#  Time (sec): 778.928       Memory: 3722.14       (MB)
#  Time (sec): 779.09        Memory: 2796.09       (MB)
#  Time (sec): 779.239       Memory: 1870.05       (MB)
#  Time (sec): 779.38        Memory: 943.997       (MB)
#  Time (sec): 779.54        Memory: 1870.05       (MB)
#  Time (sec): 786.396       Memory: 2796.09       (MB)
#  Time (sec): 786.846       Memory: 3722.14       (MB)
#  Time (sec): 787.309       Memory: 4648.19       (MB)
#  Time (sec): 801.157       Memory: 3722.14       (MB)
#  Time (sec): 801.312       Memory: 2796.09       (MB)
#  Time (sec): 801.458       Memory: 1870.05       (MB)
#  Time (sec): 801.598       Memory: 943.997       (MB)
#  Time (sec): 801.757       Memory: 1870.05       (MB)
#  Time (sec): 808.551       Memory: 2796.09       (MB)
#  Time (sec): 809.029       Memory: 3722.14       (MB)
#  Time (sec): 809.504       Memory: 4648.19       (MB)
#  Time (sec): 823.218       Memory: 3722.14       (MB)
#  Time (sec): 823.368       Memory: 2796.09       (MB)
#  Time (sec): 823.511       Memory: 1870.05       (MB)
#  Time (sec): 823.654       Memory: 943.997       (MB)
#  Time (sec): 823.814       Memory: 1870.05       (MB)
#  Time (sec): 830.7         Memory: 2796.09       (MB)
#  Time (sec): 831.173       Memory: 3722.14       (MB)
#  Time (sec): 831.639       Memory: 4648.19       (MB)
#  Time (sec): 845.475       Memory: 3722.14       (MB)
#  Time (sec): 845.62        Memory: 2796.09       (MB)
#  Time (sec): 845.759       Memory: 1870.05       (MB)
#  Time (sec): 845.9         Memory: 943.997       (MB)
#  Time (sec): 846.06        Memory: 1870.05       (MB)
#  Time (sec): 852.921       Memory: 2796.09       (MB)
#  Time (sec): 853.389       Memory: 3722.14       (MB)
#  Time (sec): 853.854       Memory: 4648.19       (MB)
#  Time (sec): 867.626       Memory: 3722.14       (MB)
#  Time (sec): 867.787       Memory: 2796.09       (MB)
#  Time (sec): 867.937       Memory: 1870.05       (MB)
#  Time (sec): 868.08        Memory: 943.997       (MB)
#  Time (sec): 868.242       Memory: 1870.05       (MB)
#  Time (sec): 875.077       Memory: 2796.09       (MB)
#  Time (sec): 875.55        Memory: 3722.14       (MB)
#  Time (sec): 876.079       Memory: 4648.19       (MB)
#  Time (sec): 889.83        Memory: 3722.14       (MB)
#  Time (sec): 889.968       Memory: 2796.09       (MB)
#  Time (sec): 890.105       Memory: 1870.05       (MB)
#  Time (sec): 890.242       Memory: 943.997       (MB)
#  Time (sec): 890.402       Memory: 1870.05       (MB)
#  Time (sec): 897.309       Memory: 2796.09       (MB)
#  Time (sec): 897.78        Memory: 3722.14       (MB)
#  Time (sec): 898.249       Memory: 4648.19       (MB)
#  Time (sec): 912.046       Memory: 3722.14       (MB)
#  Time (sec): 912.183       Memory: 2796.09       (MB)
#  Time (sec): 912.322       Memory: 1870.05       (MB)
#  Time (sec): 912.462       Memory: 943.997       (MB)
#  Time (sec): 912.622       Memory: 1870.05       (MB)
#  Time (sec): 919.506       Memory: 2796.09       (MB)
#  Time (sec): 919.974       Memory: 3722.14       (MB)
#  Time (sec): 920.44        Memory: 4648.19       (MB)
#  Time (sec): 934.213       Memory: 3722.14       (MB)
#  Time (sec): 934.382       Memory: 2796.09       (MB)
#  Time (sec): 934.548       Memory: 1870.05       (MB)
#  Time (sec): 934.694       Memory: 943.997       (MB)
#  Time (sec): 934.853       Memory: 1870.05       (MB)
#  Time (sec): 941.708       Memory: 2796.09       (MB)
#  Time (sec): 942.174       Memory: 3722.14       (MB)
#  Time (sec): 942.64        Memory: 4648.19       (MB)
#  Time (sec): 956.467       Memory: 3722.14       (MB)
#  Time (sec): 956.614       Memory: 2796.09       (MB)
#  Time (sec): 956.759       Memory: 1870.05       (MB)
#  Time (sec): 956.901       Memory: 943.997       (MB)
#  Time (sec): 957.059       Memory: 1870.05       (MB)
#  Time (sec): 963.892       Memory: 2796.09       (MB)
#  Time (sec): 964.403       Memory: 3722.14       (MB)
#  Time (sec): 964.847       Memory: 4648.19       (MB)
#  Time (sec): 978.684       Memory: 3722.14       (MB)
#  Time (sec): 978.856       Memory: 2796.09       (MB)
#  Time (sec): 979.024       Memory: 1870.05       (MB)
#  Time (sec): 979.166       Memory: 943.997       (MB)
#  Time (sec): 979.325       Memory: 1870.05       (MB)
#  Time (sec): 986.147       Memory: 2796.09       (MB)
#  Time (sec): 986.619       Memory: 3722.14       (MB)
#  Time (sec): 987.09        Memory: 4648.19       (MB)
#  Time (sec): 1000.91       Memory: 3722.14       (MB)
#  Time (sec): 1001.08       Memory: 2796.09       (MB)
#  Time (sec): 1001.23       Memory: 1870.05       (MB)
""

os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_GR_phasepair_8.lua")
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 80 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-4]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-4]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-4]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-4]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-4]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-4]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-4]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-4]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-4]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-4]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-4]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-4]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-4]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-4]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-4]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-4]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-4]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-4]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-4]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-4]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-4]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-4]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-4]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-4]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-4]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-4]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-4]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-4]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-4]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-4]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-4]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-4]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 55 elements:
# #=====================================================
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.092e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.269619
#   cosmology_OmegaLambda          : 0.680246
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.050041
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.6688
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : LCDM
#   cosmology_ns                   : 0.9626
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : GR
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : true
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_8
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_GR_phasepair_8
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              50 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [LCDM]
# # Omegab      : 0.050041
# # OmegaM      : 0.31966
# # OmegaMNu    : 0
# # OmegaCDM    : 0.269619
# # OmegaLambda : 0.680247
# # OmegaR      : 5.52858e-05
# # OmegaNu     : 3.8245e-05
# # OmegaRtot   : 9.35309e-05
# # OmegaK      : 0
# # h           : 0.6688
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 2.092e-09
# # ns          : 0.9626
# # kpivot      : 0.05 1/Mpc
# #=====================================================
#
# #=====================================================
# # GravityModel is [GR] and has the cosmology: [LCDM]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_GR_phasepair_8
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : true
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 50
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_8
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      2.44578         497479
# 0.00251653      5.49082         482322
# 0.00621709      10.8351         438416
# 0.0153593       15.5555         339910
# 0.0379453       10.3036         179007
# 0.0937441       4.03561         72490.7
# 0.231595        0.932724        22550.5
# 0.572157        0.155005        5948.47
# 1.41352         0.0198753       1378.29
# 3.4921          0.00218239      295.531
# 8.62724         0.000215887     60.1453
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 13.9091 (Mpc/h)^3
# k =  0.10: P(k,zini) = 3.58218 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0445885 (Mpc/h)^3
# k = 10.00: P(k,zini) = 0.000146855 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.814216
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.733218 Mpc/h
# Maximum 1LPT velocity: 292.516 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.0102137 Mpc/h
# Maximum 2LPT velocity: 8.17004 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 50
# Step: 0    / 50
# Positions  from z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# Step: 1    / 50
# Positions  from z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# Step: 2    / 50
# Positions  from z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# Step: 3    / 50
# Positions  from z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# Step: 4    / 50
# Positions  from z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# Step: 5    / 50
# Positions  from z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# Step: 6    / 50
# Positions  from z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# Step: 7    / 50
# Positions  from z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# Step: 8    / 50
# Positions  from z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# Step: 9    / 50
# Positions  from z = 4.09165         -> 3.62963
# Velocities from z = 4.35906         -> 3.84966
# Step: 10   / 50
# Positions  from z = 3.62963         -> 3.24448
# Velocities from z = 3.84966         -> 3.4287
# Step: 11   / 50
# Positions  from z = 3.24448         -> 2.9185
# Velocities from z = 3.4287          -> 3.07498
# Step: 12   / 50
# Positions  from z = 2.9185          -> 2.63901
# Velocities from z = 3.07498         -> 2.77358
# Step: 13   / 50
# Positions  from z = 2.63901         -> 2.39674
# Velocities from z = 2.77358         -> 2.5137
# Step: 14   / 50
# Positions  from z = 2.39674         -> 2.18471
# Velocities from z = 2.5137          -> 2.28731
# Step: 15   / 50
# Positions  from z = 2.18471         -> 1.9976
# Velocities from z = 2.28731         -> 2.08833
# Step: 16   / 50
# Positions  from z = 1.9976          -> 1.83126
# Velocities from z = 2.08833         -> 1.91206
# Step: 17   / 50
# Positions  from z = 1.83126         -> 1.6824
# Velocities from z = 1.91206         -> 1.75482
# Step: 18   / 50
# Positions  from z = 1.6824          -> 1.54842
# Velocities from z = 1.75482         -> 1.6137
# Step: 19   / 50
# Positions  from z = 1.54842         -> 1.42718
# Velocities from z = 1.6137          -> 1.48633
# Step: 20   / 50
# Positions  from z = 1.42718         -> 1.31696
# Velocities from z = 1.48633         -> 1.37079
# Step: 21   / 50
# Positions  from z = 1.31696         -> 1.21631
# Velocities from z = 1.37079         -> 1.26552
# Step: 22   / 50
# Positions  from z = 1.21631         -> 1.12404
# Velocities from z = 1.26552         -> 1.1692
# Step: 23   / 50
# Positions  from z = 1.12404         -> 1.03915
# Velocities from z = 1.1692          -> 1.08073
# Step: 24   / 50
# Positions  from z = 1.03915         -> 0.960784
# Velocities from z = 1.08073         -> 0.9992
# Step: 25   / 50
# Positions  from z = 0.960784        -> 0.888218
# Velocities from z = 0.9992          -> 0.923817
# Step: 26   / 50
# Positions  from z = 0.888218        -> 0.82083
# Velocities from z = 0.923817        -> 0.853912
# Step: 27   / 50
# Positions  from z = 0.82083         -> 0.758087
# Velocities from z = 0.853912        -> 0.788909
# Step: 28   / 50
# Positions  from z = 0.758087        -> 0.699524
# Velocities from z = 0.788909        -> 0.72831
# Step: 29   / 50
# Positions  from z = 0.699524        -> 0.644737
# Velocities from z = 0.72831         -> 0.671682
# Step: 30   / 50
# Positions  from z = 0.644737        -> 0.593372
# Velocities from z = 0.671682        -> 0.618647
# Step: 31   / 50
# Positions  from z = 0.593372        -> 0.545117
# Velocities from z = 0.618647        -> 0.568874
# Step: 32   / 50
# Positions  from z = 0.545117        -> 0.4997
# Velocities from z = 0.568874        -> 0.52207
# Step: 33   / 50
# Positions  from z = 0.4997          -> 0.456876
# Velocities from z = 0.52207         -> 0.477978
# Step: 34   / 50
# Positions  from z = 0.456876        -> 0.416431
# Velocities from z = 0.477978        -> 0.436369
# Step: 35   / 50
# Positions  from z = 0.416431        -> 0.37817
# Velocities from z = 0.436369        -> 0.397038
# Step: 36   / 50
# Positions  from z = 0.37817         -> 0.341922
# Velocities from z = 0.397038        -> 0.359804
# Step: 37   / 50
# Positions  from z = 0.341922        -> 0.307531
# Velocities from z = 0.359804        -> 0.324503
# Step: 38   / 50
# Positions  from z = 0.307531        -> 0.27486
# Velocities from z = 0.324503        -> 0.290989
# Step: 39   / 50
# Positions  from z = 0.27486         -> 0.243781
# Velocities from z = 0.290989        -> 0.259129
# Step: 40   / 50
# Positions  from z = 0.243781        -> 0.214182
# Velocities from z = 0.259129        -> 0.228803
# Step: 41   / 50
# Positions  from z = 0.214182        -> 0.185958
# Velocities from z = 0.228803        -> 0.199904
# Step: 42   / 50
# Positions  from z = 0.185958        -> 0.159017
# Velocities from z = 0.199904        -> 0.172333
# Step: 43   / 50
# Positions  from z = 0.159017        -> 0.133273
# Velocities from z = 0.172333        -> 0.146
# Step: 44   / 50
# Positions  from z = 0.133273        -> 0.108647
# Velocities from z = 0.146           -> 0.120825
# Step: 45   / 50
# Positions  from z = 0.108647        -> 0.0850694
# Velocities from z = 0.120825        -> 0.0967317
# Step: 46   / 50
# Positions  from z = 0.0850694       -> 0.0624734
# Velocities from z = 0.0967317       -> 0.0736526
# Step: 47   / 50
# Positions  from z = 0.0624734       -> 0.0407993
# Velocities from z = 0.0736526       -> 0.0515247
# Step: 48   / 50
# Positions  from z = 0.0407993       -> 0.0199918
# Velocities from z = 0.0515247       -> 0.0302905
# Step: 49   / 50
# Positions  from z = 0.0199918       -> 0
# Velocities from z = 0.0302905       -> 0.00989699
# Step: 50   / 50
# Positions  from z = 0               -> 0
# Velocities from z = 0.00989699      -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 50 Total steps taken: 0
# Positions from  z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# deltatime_pos = 7.19816         deltatime_vel = 5.48645
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00052026
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000116329
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4189357 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5687 %% (min)
# #               50.336 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4705.94         MB (min over tasks)
# # Current RSS: 4706.91         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4807.79         MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 50 Total steps taken: 1
# Positions from  z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# deltatime_pos = 3.22722         deltatime_vel = 4.41666
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00134492
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000206454
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4185085 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5081 %% (min)
# #               50.4638 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4707.48         MB (min over tasks)
# # Current RSS: 4713.67         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4809.32         MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 50 Total steps taken: 2
# Positions from  z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# deltatime_pos = 1.93234         deltatime_vel = 2.40852
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.000924961
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000220722
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4180223 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.3562 %% (min)
# #               50.6307 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4686.57         MB (min over tasks)
# # Current RSS: 4715            MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4814.3          MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 50 Total steps taken: 3
# Positions from  z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# deltatime_pos = 1.32148         deltatime_vel = 1.5665
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.000734174
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00027664
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4177148 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.19 %% (min)
# #               50.8213 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4689.11         MB (min over tasks)
# # Current RSS: 4716.4          MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4815.56         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 50 Total steps taken: 4
# Positions from  z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# deltatime_pos = 0.976417        deltatime_vel = 1.12169
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.000738164
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000609073
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4173991 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.0096 %% (min)
# #               51.0142 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4690.82         MB (min over tasks)
# # Current RSS: 4718.23         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4815.56         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 50 Total steps taken: 5
# Positions from  z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# deltatime_pos = 0.759032        deltatime_vel = 0.853426
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.000761902
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000806928
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4171185 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.8353 %% (min)
# #               51.184 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4692.39         MB (min over tasks)
# # Current RSS: 4719.73         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4816.72         MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 50 Total steps taken: 6
# Positions from  z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# deltatime_pos = 0.6116          deltatime_vel = 0.677013
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00101523
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00137165
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4168586 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.6672 %% (min)
# #               51.3529 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4694.16         MB (min over tasks)
# # Current RSS: 4721.24         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4819.85         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 50 Total steps taken: 7
# Positions from  z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# deltatime_pos = 0.506125        deltatime_vel = 0.553671
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00144026
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00176852
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4166233 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.5086 %% (min)
# #               51.5199 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4695.67         MB (min over tasks)
# # Current RSS: 4722.72         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4820.41         MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 50 Total steps taken: 8
# Positions from  z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# deltatime_pos = 0.427543        deltatime_vel = 0.463402
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00162343
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00206986
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4163349 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.3428 %% (min)
# #               51.6939 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4697.12         MB (min over tasks)
# # Current RSS: 4724.24         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4822.96         MB (max over tasks)
# #=====================================================
#
# Taking substep: 9 / 50 Total steps taken: 9
# Positions from  z = 4.09165         -> 3.62963
# Velocities from z = 4.35906         -> 3.84966
# deltatime_pos = 0.367097        deltatime_vel = 0.394948
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00169009
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00207841
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4159993 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.1635 %% (min)
# #               51.8657 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4698.74         MB (min over tasks)
# # Current RSS: 4725.76         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4824.13         MB (max over tasks)
# #=====================================================
#
# Taking substep: 10 / 50 Total steps taken: 10
# Positions from  z = 3.62963         -> 3.24448
# Velocities from z = 3.84966         -> 3.4287
# deltatime_pos = 0.319383        deltatime_vel = 0.341541
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00163411
# [Kick] + [Drift] COLA 2LPT
# [Kick] Max delta_vel * delta_time : 0.00171375
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00298851
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4141212 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               47.1328 %% (min)
# #               52.8469 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4707.28         MB (min over tasks)
# # Current RSS: 4734.79         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4835.2          MB (max over tasks)
# #=====================================================
#
# Taking substep: 16 / 50 Total steps taken: 16
# Positions from  z = 1.9976          -> 1.83126
# Velocities from z = 2.08833         -> 1.91206
# deltatime_pos = 0.165319        deltatime_vel = 0.173152
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00155182
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00302376
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4138385 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.9599 %% (min)
# #               53.0062 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4708.73         MB (min over tasks)
# # Current RSS: 4736.32         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4837.03         MB (max over tasks)
# #=====================================================
#
# Taking substep: 17 / 50 Total steps taken: 17
# Positions from  z = 1.83126         -> 1.6824
# Velocities from z = 1.91206         -> 1.75482
# deltatime_pos = 0.151026        deltatime_vel = 0.157867
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00153719
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00314619
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4136157 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.7781 %% (min)
# #               53.1664 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4710.13         MB (min over tasks)
# # Current RSS: 4737.83         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4838.86         MB (max over tasks)
# #=====================================================
#
# Taking substep: 18 / 50 Total steps taken: 18
# Positions from  z = 1.6824          -> 1.54842
# Velocities from z = 1.75482         -> 1.6137
# deltatime_pos = 0.138479        deltatime_vel = 0.144499
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00190427
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00376328
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4134277 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.5999 %% (min)
# #               53.3118 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4711.76         MB (min over tasks)
# # Current RSS: 4739.35         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4840.69         MB (max over tasks)
# #=====================================================
#
# Taking substep: 19 / 50 Total steps taken: 19
# Positions from  z = 1.54842         -> 1.42718
# Velocities from z = 1.6137          -> 1.48633
# deltatime_pos = 0.127387        deltatime_vel = 0.132721
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00195025
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00372064
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4133620 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.4248 %% (min)
# #               53.4548 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4713.14         MB (min over tasks)
# # Current RSS: 4740.87         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4842.5          MB (max over tasks)
# #=====================================================
#
# Taking substep: 20 / 50 Total steps taken: 20
# Positions from  z = 1.42718         -> 1.31696
# Velocities from z = 1.48633         -> 1.37079
# deltatime_pos = 0.117519        deltatime_vel = 0.122274
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00157219
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00371971
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4133584 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.2554 %% (min)
# #               53.5905 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4714.5          MB (min over tasks)
# # Current RSS: 4742.38         MB (max over tasks)
# # Peak RSS:    4806.31         MB (min over tasks)
# # Peak RSS:    4844.3          MB (max over tasks)
# #=====================================================
#
# Taking substep: 21 / 50 Total steps taken: 21
# Positions from  z = 1.31696         -> 1.21631
# Velocities from z = 1.37079         -> 1.26552
# deltatime_pos = 0.108691        deltatime_vel = 0.112952
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00167358
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00368166
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4133133 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               46.0738 %% (min)
# #               53.7227 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4716.09         MB (min over tasks)
# # Current RSS: 4743.89         MB (max over tasks)
# # Peak RSS:    4806.61         MB (min over tasks)
# # Peak RSS:    4846.08         MB (max over tasks)
# #=====================================================
#
# Taking substep: 22 / 50 Total steps taken: 22
# Positions from  z = 1.21631         -> 1.12404
# Velocities from z = 1.26552         -> 1.1692
# deltatime_pos = 0.100754        deltatime_vel = 0.104591
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00142242
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00383507
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4131391 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               45.8934 %% (min)
# #               53.8488 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4717.52         MB (min over tasks)
# # Current RSS: 4745.42         MB (max over tasks)
# # Peak RSS:    4806.72         MB (min over tasks)
# # Peak RSS:    4847.68         MB (max over tasks)
# #=====================================================
#
# Taking substep: 23 / 50 Total steps taken: 23
# Positions from  z = 1.12404         -> 1.03915
# Velocities from z = 1.1692          -> 1.08073
# deltatime_pos = 0.0935856       deltatime_vel = 0.0970557
# Adding particles (baryons+CDM) to the densityfield
# [Kick] Max delta_vel * delta_time : 0.00160541
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00373784
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4129407 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               45.7084 %% (min)
# #               53.9628 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# ...
#  Time (sec): 336.185       Memory: 2796.09       (MB)
#  Time (sec): 336.326       Memory: 1870.05       (MB)
#  Time (sec): 336.467       Memory: 943.997       (MB)
#  Time (sec): 336.627       Memory: 1870.05       (MB)
#  Time (sec): 343.408       Memory: 2796.09       (MB)
#  Time (sec): 343.877       Memory: 3722.14       (MB)
#  Time (sec): 344.4         Memory: 4648.19       (MB)
#  Time (sec): 358.127       Memory: 3722.14       (MB)
#  Time (sec): 358.281       Memory: 2796.09       (MB)
#  Time (sec): 358.441       Memory: 1870.05       (MB)
#  Time (sec): 358.586       Memory: 943.997       (MB)
#  Time (sec): 358.744       Memory: 1870.05       (MB)
#  Time (sec): 365.443       Memory: 2796.09       (MB)
#  Time (sec): 365.912       Memory: 3722.14       (MB)
#  Time (sec): 366.377       Memory: 4648.19       (MB)
#  Time (sec): 380.196       Memory: 3722.14       (MB)
#  Time (sec): 380.342       Memory: 2796.09       (MB)
#  Time (sec): 380.492       Memory: 1870.05       (MB)
#  Time (sec): 380.634       Memory: 943.997       (MB)
#  Time (sec): 380.796       Memory: 1870.05       (MB)
#  Time (sec): 387.593       Memory: 2796.09       (MB)
#  Time (sec): 388.051       Memory: 3722.14       (MB)
#  Time (sec): 388.517       Memory: 4648.19       (MB)
#  Time (sec): 402.43        Memory: 3722.14       (MB)
#  Time (sec): 402.584       Memory: 2796.09       (MB)
#  Time (sec): 402.742       Memory: 1870.05       (MB)
#  Time (sec): 402.887       Memory: 943.997       (MB)
#  Time (sec): 403.05        Memory: 1870.05       (MB)
#  Time (sec): 409.824       Memory: 2796.09       (MB)
#  Time (sec): 410.291       Memory: 3722.14       (MB)
#  Time (sec): 410.753       Memory: 4648.19       (MB)
#  Time (sec): 424.518       Memory: 3722.14       (MB)
#  Time (sec): 424.664       Memory: 2796.09       (MB)
#  Time (sec): 424.81        Memory: 1870.05       (MB)
#  Time (sec): 424.953       Memory: 943.997       (MB)
#  Time (sec): 425.111       Memory: 1870.05       (MB)
#  Time (sec): 431.908       Memory: 2796.09       (MB)
#  Time (sec): 432.438       Memory: 3722.14       (MB)
#  Time (sec): 432.9         Memory: 4648.19       (MB)
#  Time (sec): 446.55        Memory: 3722.14       (MB)
#  Time (sec): 446.695       Memory: 2796.09       (MB)
#  Time (sec): 446.84        Memory: 1870.05       (MB)
#  Time (sec): 446.996       Memory: 943.997       (MB)
#  Time (sec): 447.155       Memory: 1870.05       (MB)
#  Time (sec): 453.965       Memory: 2796.09       (MB)
#  Time (sec): 454.494       Memory: 3722.14       (MB)
#  Time (sec): 454.96        Memory: 4648.19       (MB)
#  Time (sec): 468.724       Memory: 3722.14       (MB)
#  Time (sec): 468.871       Memory: 2796.09       (MB)
#  Time (sec): 469.015       Memory: 1870.05       (MB)
#  Time (sec): 469.154       Memory: 943.997       (MB)
#  Time (sec): 469.314       Memory: 1870.05       (MB)
#  Time (sec): 476.119       Memory: 2796.09       (MB)
#  Time (sec): 476.586       Memory: 3722.14       (MB)
#  Time (sec): 477.05        Memory: 4648.19       (MB)
#  Time (sec): 490.833       Memory: 3722.14       (MB)
#  Time (sec): 490.978       Memory: 2796.09       (MB)
#  Time (sec): 491.118       Memory: 1870.05       (MB)
#  Time (sec): 491.262       Memory: 943.997       (MB)
#  Time (sec): 491.423       Memory: 1870.05       (MB)
#  Time (sec): 498.429       Memory: 2796.09       (MB)
#  Time (sec): 498.901       Memory: 3722.14       (MB)
#  Time (sec): 499.369       Memory: 4648.19       (MB)
#  Time (sec): 513.217       Memory: 3722.14       (MB)
#  Time (sec): 513.357       Memory: 2796.09       (MB)
#  Time (sec): 513.497       Memory: 1870.05       (MB)
#  Time (sec): 513.639       Memory: 943.997       (MB)
#  Time (sec): 513.8         Memory: 1870.05       (MB)
#  Time (sec): 520.605       Memory: 2796.09       (MB)
#  Time (sec): 521.133       Memory: 3722.14       (MB)
#  Time (sec): 521.584       Memory: 4648.19       (MB)
#  Time (sec): 535.4         Memory: 3722.14       (MB)
#  Time (sec): 535.564       Memory: 2796.09       (MB)
#  Time (sec): 535.717       Memory: 1870.05       (MB)
#  Time (sec): 535.861       Memory: 943.997       (MB)
#  Time (sec): 536.021       Memory: 1870.05       (MB)
#  Time (sec): 542.742       Memory: 2796.09       (MB)
#  Time (sec): 543.214       Memory: 3722.14       (MB)
#  Time (sec): 543.683       Memory: 4648.19       (MB)
#  Time (sec): 557.523       Memory: 3722.14       (MB)
#  Time (sec): 557.67        Memory: 2796.09       (MB)
#  Time (sec): 557.811       Memory: 1870.05       (MB)
#  Time (sec): 557.954       Memory: 943.997       (MB)
#  Time (sec): 558.114       Memory: 1870.05       (MB)
#  Time (sec): 564.964       Memory: 2796.09       (MB)
#  Time (sec): 565.438       Memory: 3722.14       (MB)
#  Time (sec): 565.906       Memory: 4648.19       (MB)
#  Time (sec): 579.713       Memory: 3722.14       (MB)
#  Time (sec): 579.865       Memory: 2796.09       (MB)
#  Time (sec): 580.015       Memory: 1870.05       (MB)
#  Time (sec): 580.157       Memory: 943.997       (MB)
#  Time (sec): 580.316       Memory: 1870.05       (MB)
#  Time (sec): 587.159       Memory: 2796.09       (MB)
#  Time (sec): 587.628       Memory: 3722.14       (MB)
#  Time (sec): 588.09        Memory: 4648.19       (MB)
#  Time (sec): 601.916       Memory: 3722.14       (MB)
#  Time (sec): 602.07        Memory: 2796.09       (MB)
#  Time (sec): 602.218       Memory: 1870.05       (MB)
#  Time (sec): 602.36        Memory: 943.997       (MB)
#  Time (sec): 602.522       Memory: 1870.05       (MB)
#  Time (sec): 609.346       Memory: 2796.09       (MB)
#  Time (sec): 609.811       Memory: 3722.14       (MB)
#  Time (sec): 610.277       Memory: 4648.19       (MB)
#  Time (sec): 624.158       Memory: 3722.14       (MB)
#  Time (sec): 624.327       Memory: 2796.09       (MB)
#  Time (sec): 624.468       Memory: 1870.05       (MB)
#  Time (sec): 624.611       Memory: 943.997       (MB)
#  Time (sec): 624.766       Memory: 1870.05       (MB)
#  Time (sec): 631.553       Memory: 2796.09       (MB)
#  Time (sec): 632.106       Memory: 3722.14       (MB)
#  Time (sec): 632.575       Memory: 4648.19       (MB)
#  Time (sec): 646.3         Memory: 3722.14       (MB)
#  Time (sec): 646.456       Memory: 2796.09       (MB)
#  Time (sec): 646.607       Memory: 1870.05       (MB)
#  Time (sec): 646.751       Memory: 943.997       (MB)
#  Time (sec): 646.91        Memory: 1870.05       (MB)
#  Time (sec): 653.768       Memory: 2796.09       (MB)
#  Time (sec): 654.238       Memory: 3722.14       (MB)
#  Time (sec): 654.704       Memory: 4648.19       (MB)
#  Time (sec): 668.514       Memory: 3722.14       (MB)
#  Time (sec): 668.654       Memory: 2796.09       (MB)
#  Time (sec): 668.791       Memory: 1870.05       (MB)
#  Time (sec): 668.93        Memory: 943.997       (MB)
#  Time (sec): 669.091       Memory: 1870.05       (MB)
#  Time (sec): 675.885       Memory: 2796.09       (MB)
#  Time (sec): 676.358       Memory: 3722.14       (MB)
#  Time (sec): 676.832       Memory: 4648.19       (MB)
#  Time (sec): 690.551       Memory: 3722.14       (MB)
#  Time (sec): 690.689       Memory: 2796.09       (MB)
#  Time (sec): 690.829       Memory: 1870.05       (MB)
#  Time (sec): 690.973       Memory: 943.997       (MB)
#  Time (sec): 691.134       Memory: 1870.05       (MB)
#  Time (sec): 697.94        Memory: 2796.09       (MB)
#  Time (sec): 698.414       Memory: 3722.14       (MB)
#  Time (sec): 698.88        Memory: 4648.19       (MB)
#  Time (sec): 712.741       Memory: 3722.14       (MB)
#  Time (sec): 712.88        Memory: 2796.09       (MB)
#  Time (sec): 713.019       Memory: 1870.05       (MB)
#  Time (sec): 713.157       Memory: 943.997       (MB)
#  Time (sec): 713.316       Memory: 1870.05       (MB)
#  Time (sec): 720.112       Memory: 2796.09       (MB)
#  Time (sec): 720.597       Memory: 3722.14       (MB)
#  Time (sec): 721.074       Memory: 4648.19       (MB)
#  Time (sec): 734.867       Memory: 3722.14       (MB)
#  Time (sec): 735.014       Memory: 2796.09       (MB)
#  Time (sec): 735.16        Memory: 1870.05       (MB)
#  Time (sec): 735.312       Memory: 943.997       (MB)
#  Time (sec): 735.474       Memory: 1870.05       (MB)
#  Time (sec): 742.342       Memory: 2796.09       (MB)
#  Time (sec): 742.816       Memory: 3722.14       (MB)
#  Time (sec): 743.287       Memory: 4648.19       (MB)
#  Time (sec): 757.162       Memory: 3722.14       (MB)
#  Time (sec): 757.316       Memory: 2796.09       (MB)
#  Time (sec): 757.464       Memory: 1870.05       (MB)
#  Time (sec): 757.61        Memory: 943.997       (MB)
#  Time (sec): 757.77        Memory: 1870.05       (MB)
#  Time (sec): 764.601       Memory: 2796.09       (MB)
#  Time (sec): 765.074       Memory: 3722.14       (MB)
#  Time (sec): 765.542       Memory: 4648.19       (MB)
#  Time (sec): 779.313       Memory: 3722.14       (MB)
#  Time (sec): 779.456       Memory: 2796.09       (MB)
#  Time (sec): 779.595       Memory: 1870.05       (MB)
#  Time (sec): 779.736       Memory: 943.997       (MB)
#  Time (sec): 779.896       Memory: 1870.05       (MB)
#  Time (sec): 786.68        Memory: 2796.09       (MB)
#  Time (sec): 787.148       Memory: 3722.14       (MB)
#  Time (sec): 787.611       Memory: 4648.19       (MB)
#  Time (sec): 801.413       Memory: 3722.14       (MB)
#  Time (sec): 801.558       Memory: 2796.09       (MB)
#  Time (sec): 801.699       Memory: 1870.05       (MB)
#  Time (sec): 801.84        Memory: 943.997       (MB)
#  Time (sec): 802.001       Memory: 1870.05       (MB)
#  Time (sec): 808.851       Memory: 2796.09       (MB)
#  Time (sec): 809.323       Memory: 3722.14       (MB)
#  Time (sec): 809.792       Memory: 4648.19       (MB)
#  Time (sec): 823.581       Memory: 3722.14       (MB)
#  Time (sec): 823.721       Memory: 2796.09       (MB)
#  Time (sec): 823.859       Memory: 1870.05       (MB)
#  Time (sec): 824           Memory: 943.997       (MB)
#  Time (sec): 824.159       Memory: 1870.05       (MB)
#  Time (sec): 830.984       Memory: 2796.09       (MB)
#  Time (sec): 831.452       Memory: 3722.14       (MB)
#  Time (sec): 831.917       Memory: 4648.19       (MB)
#  Time (sec): 845.802       Memory: 3722.14       (MB)
#  Time (sec): 845.943       Memory: 2796.09       (MB)
#  Time (sec): 846.084       Memory: 1870.05       (MB)
#  Time (sec): 846.227       Memory: 943.997       (MB)
#  Time (sec): 846.388       Memory: 1870.05       (MB)
#  Time (sec): 853.242       Memory: 2796.09       (MB)
#  Time (sec): 853.711       Memory: 3722.14       (MB)
#  Time (sec): 854.177       Memory: 4648.19       (MB)
#  Time (sec): 867.977       Memory: 3722.14       (MB)
#  Time (sec): 868.115       Memory: 2796.09       (MB)
#  Time (sec): 868.254       Memory: 1870.05       (MB)
#  Time (sec): 868.393       Memory: 943.997       (MB)
#  Time (sec): 868.554       Memory: 1870.05       (MB)
#  Time (sec): 875.373       Memory: 2796.09       (MB)
#  Time (sec): 875.855       Memory: 3722.14       (MB)
#  Time (sec): 876.337       Memory: 4648.19       (MB)
#  Time (sec): 890.118       Memory: 3722.14       (MB)
#  Time (sec): 890.257       Memory: 2796.09       (MB)
#  Time (sec): 890.397       Memory: 1870.05       (MB)
#  Time (sec): 890.54        Memory: 943.997       (MB)
#  Time (sec): 890.701       Memory: 1870.05       (MB)
#  Time (sec): 897.525       Memory: 2796.09       (MB)
#  Time (sec): 897.997       Memory: 3722.14       (MB)
#  Time (sec): 898.523       Memory: 4648.19       (MB)
#  Time (sec): 912.249       Memory: 3722.14       (MB)
#  Time (sec): 912.386       Memory: 2796.09       (MB)
#  Time (sec): 912.525       Memory: 1870.05       (MB)
#  Time (sec): 912.664       Memory: 943.997       (MB)
#  Time (sec): 912.826       Memory: 1870.05       (MB)
#  Time (sec): 919.602       Memory: 2796.09       (MB)
#  Time (sec): 920.124       Memory: 3722.14       (MB)
#  Time (sec): 920.564       Memory: 4648.19       (MB)
#  Time (sec): 934.295       Memory: 3722.14       (MB)
#  Time (sec): 934.44        Memory: 2796.09       (MB)
#  Time (sec): 934.582       Memory: 1870.05       (MB)
#  Time (sec): 934.725       Memory: 943.997       (MB)
#  Time (sec): 934.885       Memory: 1870.05       (MB)
#  Time (sec): 941.683       Memory: 2796.09       (MB)
#  Time (sec): 942.145       Memory: 3722.14       (MB)
#  Time (sec): 942.615       Memory: 4648.19       (MB)
#  Time (sec): 956.391       Memory: 3722.14       (MB)
#  Time (sec): 956.561       Memory: 2796.09       (MB)
#  Time (sec): 956.736       Memory: 1870.05       (MB)
#  Time (sec): 956.882       Memory: 943.997       (MB)
#  Time (sec): 957.024       Memory: 1870.05       (MB)
#  Time (sec): 963.877       Memory: 2796.09       (MB)
#  Time (sec): 964.344       Memory: 3722.14       (MB)
#  Time (sec): 964.808       Memory: 4648.19       (MB)
#  Time (sec): 978.625       Memory: 3722.14       (MB)
#  Time (sec): 978.773       Memory: 2796.09       (MB)
#  Time (sec): 978.913       Memory: 1870.05       (MB)
#  Time (sec): 979.056       Memory: 943.997       (MB)
#  Time (sec): 979.216       Memory: 1870.05       (MB)
#  Time (sec): 986.049       Memory: 2796.09       (MB)
#  Time (sec): 986.523       Memory: 3722.14       (MB)
#  Time (sec): 986.993       Memory: 4648.19       (MB)
#  Time (sec): 1000.73       Memory: 3722.14       (MB)
#  Time (sec): 1000.87       Memory: 2796.09       (MB)
#  Time (sec): 1001.01       Memory: 1870.05       (MB)
#  Time (sec): 1001.15       Memory: 943.997       (MB)
#  Time (sec): 1001.31       Memory: 1870.05       (MB)
#  Time (sec): 1008.12       Memory: 2796.09       (MB)
#  Time (sec): 1008.64       Memory: 3722.14       (MB)
#  Time (sec): 1009.11       Memory: 4648.19       (MB)
#  Time (sec): 1022.89       Memory: 3722.14       (MB)
#  Time (sec): 1023.05       Memory: 2796.09       (MB)
#  Time (sec): 1023.2        Memory: 1870.05       (MB)
#  Time (sec): 1023.35       Memory: 943.997       (MB)
#  Time (sec): 1023.51       Memory: 1870.05       (MB)
#  Time (sec): 1030.37       Memory: 2796.09       (MB)
#  Time (sec): 1030.84       Memory: 3722.14       (MB)
#  Time (sec): 1031.33       Memory: 4648.19       (MB)
#  Time (sec): 1045.16       Memory: 3722.14       (MB)
#  Time (sec): 1045.31       Memory: 2796.09       (MB)
#  Time (sec): 1045.45       Memory: 1870.05       (MB)
#  Time (sec): 1045.59       Memory: 943.997       (MB)
#  Time (sec): 1045.75       Memory: 1870.05       (MB)
#  Time (sec): 1052.61       Memory: 2796.09       (MB)
#  Time (sec): 1053.07       Memory: 3722.14       (MB)
#  Time (sec): 1053.6        Memory: 4648.19       (MB)
#  Time (sec): 1067.39       Memory: 3722.14       (MB)
#  Time (sec): 1067.52       Memory: 2796.09       (MB)
#  Time (sec): 1067.66       Memory: 1870.05       (MB)
#  Time (sec): 1067.8        Memory: 943.997       (MB)
#  Time (sec): 1067.96       Memory: 1870.05       (MB)
#  Time (sec): 1074.8        Memory: 2796.09       (MB)
#  Time (sec): 1075.33       Memory: 3722.14       (MB)
#  Time (sec): 1075.79       Memory: 4648.19       (MB)
#  Time (sec): 1089.61       Memory: 3722.14       (MB)
#  Time (sec): 1089.77       Memory: 2796.09       (MB)
#  Time (sec): 1089.91       Memory: 1870.05       (MB)
#  Time (sec): 1090.05       Memory: 943.997       (MB)
#  Time (sec): 1090.21       Memory: 1870.05       (MB)
#  Time (sec): 1097.09       Memory: 2796.09       (MB)
#  Time (sec): 1097.56       Memory: 3722.14       (MB)
#  Time (sec): 1098.02       Memory: 4648.19       (MB)
#  Time (sec): 1111.86       Memory: 3722.14       (MB)
#  Time (sec): 1112.04       Memory: 2796.09       (MB)
#  Time (sec): 1112.19       Memory: 1870.05       (MB)
#  Time (sec): 1112.33       Memory: 943.997       (MB)
#  Time (sec): 1112.47       Memory: 1870.05       (MB)
#  Time (sec): 1119.29       Memory: 2796.09       (MB)
#  Time (sec): 1119.75       Memory: 3722.14       (MB)
#  Time (sec): 1120.22       Memory: 4648.19       (MB)
#  Time (sec): 1133.75       Memory: 3722.14       (MB)
#  Time (sec): 1133.89       Memory: 2796.09       (MB)
#  Time (sec): 1134.03       Memory: 1870.05       (MB)
#  Time (sec): 1134.18       Memory: 943.997       (MB)
#  Time (sec): 1134.98       Memory: 1926.74       (MB)
#  Time (sec): 1139.55       Memory: 2909.49       (MB)
#  Time (sec): 1153.4        Memory: 1926.74       (MB)
#  Time (sec): 1155.08       Memory: 943.997       (MB)
#
# #=====================================================
# 0
