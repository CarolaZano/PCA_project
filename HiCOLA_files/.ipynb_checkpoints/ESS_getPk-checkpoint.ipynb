# %%
from configobj import ConfigObj
import numpy as np
import os
import matplotlib.pyplot as plt
from scipy.interpolate import CubicSpline
from scipy.interpolate import RegularGridInterpolator
import pyccl as ccl
from pyDOE2 import *
import matplotlib

#from HiCOLA import Frontend

# %%
def wr_funct(T_CMB):
    return 4.48150052e-7*T_CMB**4 *(1+ 3.044*7/8 * (4/11)**(4/3))

T_CMB = 2.72548 # K
print(wr_funct(T_CMB))
# Out:
# 4.182345109176885e-05

# %%
def T_CMB_funct(wr):
    return (wr/4.48150052e-7/(1+ 3.044*7/8 * (4/11)**(4/3)))**0.25

print(T_CMB_funct(4.28e-5))
# Out:
# 2.7410680712994577

# %%
def k_2dS_funct(f_phi,k_1dS,g_31dS,E_dS, Omg_m,Omg_r):
    return - 2*k_1dS - 12*(1-(1-f_phi)*(1-Omg_m-Omg_r)/E_dS**2)

def g_32dS_funct(f_phi,k_1dS,g_31dS,E_dS,Omg_m,Omg_r):
    k_2dS = k_2dS_funct(f_phi,k_1dS,g_31dS,E_dS,Omg_m,Omg_r)
    return 0.5 - 0.5*((1-f_phi)*(1-Omg_m-Omg_r)/E_dS**2 + k_1dS/6 + k_2dS/4 +g_31dS)

# %%
''' Define useful functions'''

def create_params(f, E, h, omegas):
    '''
    Get parameters k, g from f, E and cosmo
    Inputs:
    f --> fphi
    E --> EdS
    omegas --> [b, c, r] * h^2
    
    Outputs:
    k --> k1dS
    g --> g31dS
    '''
    
    # cosmological constant density
    o_DE = h**2 - omegas[0] - omegas[1] - omegas[2]
    O_L = (1-f)*o_DE/ h**2
    
    # k and g
    alpha = 1 - O_L/E**2
    k = -6*alpha
    g = 2*alpha
    
    return k, g

print(create_params(0.42105263157894735, 1/1.4032496307237814, 0.7307, [0.02196, 0.1274, 4.28e-5]))

# %%
# We want Omega_m , n_s    , A_s ,h,  f_phi, EdS, k_1dS, g_31dS
sample_test = np.array([(0.1274 + 0.02196)/0.7307**2, 0.9626, 2.092e-9,0.7307, 0.42105263157894735,1/1.4032496307237814,-0.34384601713152496,-8.289986166458684])

"""
k1_parameter  = -0.34384601713152496
k2_parameter = -1.460168017955791
g31_parameter = -8.289986166458684
g32_parameter = 4.445662089077228
"""
print("k_2dS test = ",k_2dS_funct(sample_test[4],sample_test[6], sample_test[7],sample_test[5], sample_test[0],4.28e-5/sample_test[3]**2))
print("g_32dS test = ",g_32dS_funct(sample_test[4],sample_test[6], sample_test[7], sample_test[5],sample_test[0],4.28e-5/sample_test[3]**2))

print("k_2dS paper = ", -1.460168017955791)
print("g_32dS paper = ",4.445662089077228)

sample_new = sample_test#np.array([0.31966, 0.9626, 2.092e-9,0.6688, 0.42105263157894735,1/1.4032496307237814,-0.34384601713152496,-8.289986166458684])

print("k_2dS = ",k_2dS_funct(sample_new[4],sample_new[6], sample_new[7],sample_test[5], sample_new[0],wr_funct(T_CMB)/sample_new[3]**2))
print("g_32dS = ",g_32dS_funct(sample_new[4],sample_new[6], sample_new[7],sample_test[5], sample_new[0],wr_funct(T_CMB)/sample_new[3]**2))

print("f_phi = ", 0.42105263157894735)
print("E_dS = ", 1/1.4032496307237814)
# Out:
# k_2dS test =  -1.460168017955791
# g_32dS test =  4.445662089077228
# k_2dS paper =  -1.460168017955791
# g_32dS paper =  4.445662089077228
# k_2dS =  -1.4601429968794721
# g_32dS =  4.445657918897842
# f_phi =  0.42105263157894735
# E_dS =  0.7126315789473684

# %%
## Power spectrum from CCL - backscaling

wr = 4.28e-5#wr_funct(T_CMB)

ns = sample_new[1]
As = sample_new[2]
h = sample_new[3]
wm = sample_new[0]*h**2
wb = 0.02196 * h**2

kk_ccl = np.logspace(-3,1,500)*h               # in 1/Mpc
cosmoLCDM = ccl.Cosmology(Omega_c=(wm - wb)/h**2,
                           Omega_b=wb/h**2, 
                           A_s=As, 
                           h = h,
                           n_s=ns,
                           Omega_k=0)

# Omega_g::: Note that if a non-None value is given, this may result in a physically 
# inconsistent model because the CMB temperature will still be non-zero in the parameters.
cosmoLCDM_norad = ccl.Cosmology(Omega_c=(wm - wb)/h**2,
                           Omega_b=wb/h**2, 
                           A_s=As, 
                           h = h,
                           n_s=ns,
                           Omega_k=0,
                           Omega_g = 0,
                           T_CMB = 0.0)

Pk_0 = ccl.power.linear_matter_power(cosmoLCDM, kk_ccl, 1)    # in (Mpc)^3

Growth_0 = ccl.background.growth_factor(cosmoLCDM_norad, 1)

Growth_49 = ccl.background.growth_factor(cosmoLCDM_norad, 1/(1+49))

Pk_ccl = (Growth_49/Growth_0)**2 * Pk_0*h**3    # in (Mpc)^3/h^3

kk_ccl = kk_ccl/h    # in h/Mpc
## Save power spectrum for initial conditions (Linear)

np.savetxt("/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat", np.array([kk_ccl, Pk_ccl]).T)

# %%
## Plot power spectra (at z = 49, expect very different from z=0)

plt.plot(kk_ccl,Pk_ccl)

plt.xscale("log")
plt.yscale("log")

# %% [markdown]
# ## Get expansion and force files

# %%
''' Define useful functions'''

def Update_ini(run, sample, num_ini):
    """
    Updates file num_ini to include the parameters (numerical)
    """
    h = sample[3]
    wr = 4.28e-5
    wb = 0.02196
    wc = sample[0]*h**2 - wb    
    
    config_n = ConfigObj(num_ini)
    keys_n = config_n.keys()
    
    config_n[keys_n[0]] = 'run_'+str(run)
    
    config_n[keys_n[6]] = str(h)
    config_n[keys_n[7]] = str(wr)
    config_n[keys_n[8]] = str(wb)
    config_n[keys_n[9]] = str(wc)
    config_n.filename = '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'
    config_n.write()

# %%
Update_ini("ESS-C", sample_new, '/home/c2042999/HiCOLA_env/Cubic_galileon_emu/numerical_parameters.ini')

# %%
command = 'cd ; cd /home/c2042999/HiCOLA_env/Hi-COLA; python3 -m HiCOLA.Frontend.generate_simulation_input /home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS-C.ini /home/c2042999/PCA_project/HiCOLA_files/numerical.ini'
os.system(command)
# Out:
# /home/c2042999/PCA_env/3.8.10/lib/python3.10/site-packages/scipy/integrate/_ivp/common.py:47: UserWarning: At least one element of `rtol` is too small. Setting `rtol = np.maximum(rtol, 2.220446049250313e-14)`.
#   warn("At least one element of `rtol` is too small. "
# Namespace(input_ini_filenames=['/home/c2042999/PCA_project/HiCOLA_files/horndeski_ESS-C.ini', '/home/c2042999/PCA_project/HiCOLA_files/numerical.ini'])
# Horndeski functions --------------
# K = X**2*k_2 + X*k_1
# G_3 = X**2*g_32 + X*g_31
# G_4 = 0.500000000000000
# Horndeski parameters--------------
# ESS-C model parameters, [k_1, k_2, g_31, g_32] = [-0.34384601713152496, -1.460168017955791, -8.289986166458684, 4.445662089077228]
# Cosmological parameters-----------
# Omega_m0 = 0.2797409788825341
# Omega_r0 = 8.016144815327033e-05
# Omega_lambda0 = 0.41694565559802316
# Initial conditions----------------
# Hubble0 = 1.4032496307237814
# scalar_prime0 = 0.9
# Closure parameter is phiprime = 1.0047609090821708
# (note: therefore one of the initial conditions or Horndeski model parameters printed above was the guess value)
# Files for Hi-COLA numerical simulation being generated.
# Files generated. Saved in /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output
# 0

# %%
## Plotting ##

fig, ax = plt.subplots(3,1, figsize=(12,8),sharex=True)
fig.subplots_adjust(hspace=0,wspace=0)

# We want Omega_m*h^2 , n_s    , A_s ,h,  f_phi
expansion_today = np.loadtxt("/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_expansion.txt")

wr = 4.28e-5#wr_funct(T_CMB)
h = sample_new[3]
wm = sample_new[0]*h**2

a_today = expansion_today.T[0]
E_a_today = expansion_today.T[1]
E_a_GR = np.sqrt((wm)*a_today**(-3) + wr*a_today**(-4) + (h**2 - (wm) -wr))/h

ax[0].plot(1/a_today -1, E_a_today/E_a_GR, alpha=0.7)
#ax[0].plot(1/a_today -1, E_a_GR, alpha=0.7)

force_today = np.loadtxt("/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_force.txt")

a_today = force_today.T[0]
chiD_today = force_today.T[1] # chi/delta
coupling = force_today.T[2]

ax[1].plot(1/a_today -1, chiD_today, alpha=0.7)

ax[2].plot(1/a_today -1, coupling, alpha=0.7)

ax[0].set_xscale("log")
ax[2].set_xlabel("z")
ax[0].set_ylabel(r"$E^{CuGal}/E^{\Lambda CDM}$")

ax[1].set_ylabel(r"$\chi/\delta$, CuGal")
ax[2].set_ylabel(r"CuGal coupling $(\beta)$")
# Out:
# Text(0, 0.5, 'CuGal coupling $(\\beta)$')

# %% [markdown]
# ## Rewrite Lua file

# %%
def rewriteluafile(k, sample,boxsize,n_particles,n_mesh):

    wb = 0.02196
    wr = 4.28e-5
    #sample = Omega_m , n_s    , A_s ,h,  f_phi, EdS, k_1dS, g_31dS, k_2dS, g_32dS
    n_s = sample[1]
    A_s = sample[2]
    h = sample[3]
    wm = sample[0]*h**2

    f_phi = sample[4]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_ESS-C_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_ESS-C_{}"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB_funct(wr))+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_expansion.txt"'+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_force.txt"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_{}"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(100+k)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = false'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
def rewriteluafile_phasepair(k, sample,boxsize,n_particles,n_mesh):

    wb = 0.02196
    wr = 4.28e-5
    #sample = Omega_m , n_s    , A_s ,h,  f_phi, EdS, k_1dS, g_31dS, k_2dS, g_32dS
    n_s = sample[1]
    A_s = sample[2]
    h = sample[3]
    wm = sample[0]*h**2

    f_phi = sample[4]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_ESS-C_phasepair_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_ESS-C_phasepair_{}"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB_funct(wr))+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_expansion.txt"'+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_force.txt"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_{}"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(100+k)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = true'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
## Create lua files

rewriteluafile(8,sample_new,400,512,1536)
# phase pair
rewriteluafile_phasepair(8,sample_new,400,512,1536)

# %%
"""Create P(k)"""

os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_ESS-C_8.lua")
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-3]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-3]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-3]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-3]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-3]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-3]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-3]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-3]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-3]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-3]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-3]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-3]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-3]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-3]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-3]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-3]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-3]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-3]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-3]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-3]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-3]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-3]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-3]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-3]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-3]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-3]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-3]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-3]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-3]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-3]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-3]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-3]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 62 elements:
# #=====================================================
#   HiCOLA_expansion_filename      : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_expansion.txt
#   HiCOLA_preforce_filename       : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_force.txt
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.092e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.238611
#   cosmology_OmegaLambda          : 0.720179
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.0411296
#   cosmology_TCMB_kelvin          : 2.74107
#   cosmology_h                    : 0.7307
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : HiCOLA
#   cosmology_ns                   : 0.9626
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : HiCOLA
#   gravity_model_HiCOLA_smoothing_filter : gaussian
#   gravity_model_HiCOLA_smoothing_scale_over_boxsize : 0.0075
#   gravity_model_screening        : true
#   gravity_model_screening_enforce_largescale_linear : true
#   gravity_model_screening_linear_scale_hmpc : 0.2
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : false
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_8
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_ESS-C_8
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              50 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [HiCOLA]
# # Omegab      : 0.0411296
# # OmegaM      : 0.279741
# # OmegaMNu    : 0
# # OmegaCDM    : 0.238611
# # OmegaLambda : 0.720179
# # OmegaR      : 4.73844e-05
# # OmegaNu     : 3.27791e-05
# # OmegaRtot   : 8.01635e-05
# # OmegaK      : 0
# # h           : 0.7307
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.74107 K
# # Tnu         : 1.96394 K
# # As          : 2.092e-09
# # ns          : 0.9626
# # kpivot      : 0.05 1/Mpc
# # HiCOLA_expansion_filename     : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_expansion.txt
# #=====================================================
#
# #=====================================================
# # GravityModel is [HiCOLA] and has the cosmology: [HiCOLA]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# # HiCOLA_preforce_filename : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_force.txt
# # Screening method : true
# # Enforce correct linear evolution : true
# # Scale for which we enforce this  : 0.2 h/Mpc
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_ESS-C_8
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : false
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 50
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_8
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      3.17809         475864
# 0.00251653      7.10803         460496
# 0.00621709      13.9011         416705
# 0.0153593       19.7767         321613
# 0.0379453       14.5802         178686
# 0.0937441       6.0765          74642.7
# 0.231595        1.51166         24090.2
# 0.572157        0.250251        6342.4
# 1.41352         0.0324636       1478.14
# 3.4921          0.00358914      318.028
# 8.62724         0.00035657      64.8626
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 17.7301 (Mpc/h)^3
# k =  0.10: P(k,zini) = 5.63202 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0725552 (Mpc/h)^3
# k = 10.00: P(k,zini) = 0.000242701 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.976588
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.886038 Mpc/h
# Maximum 1LPT velocity: 330.56 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.0165882 Mpc/h
# Maximum 2LPT velocity: 12.4101 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 50
# Step: 0    / 50
# Positions  from z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# Step: 1    / 50
# Positions  from z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# Step: 2    / 50
# Positions  from z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# Step: 3    / 50
# Positions  from z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# Step: 4    / 50
# Positions  from z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# Step: 5    / 50
# Positions  from z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# Step: 6    / 50
# Positions  from z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# Step: 7    / 50
# Positions  from z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# Step: 8    / 50
# Positions  from z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# Step: 9    / 50
# Positions  from z = 4.09165         -> 3.62963
# Velocities from z = 4.35906         -> 3.84966
# Step: 10   / 50
# Positions  from z = 3.62963         -> 3.24448
# Velocities from z = 3.84966         -> 3.4287
# Step: 11   / 50
# Positions  from z = 3.24448         -> 2.9185
# Velocities from z = 3.4287          -> 3.07498
# Step: 12   / 50
# Positions  from z = 2.9185          -> 2.63901
# Velocities from z = 3.07498         -> 2.77358
# Step: 13   / 50
# Positions  from z = 2.63901         -> 2.39674
# Velocities from z = 2.77358         -> 2.5137
# Step: 14   / 50
# Positions  from z = 2.39674         -> 2.18471
# Velocities from z = 2.5137          -> 2.28731
# Step: 15   / 50
# Positions  from z = 2.18471         -> 1.9976
# Velocities from z = 2.28731         -> 2.08833
# Step: 16   / 50
# Positions  from z = 1.9976          -> 1.83126
# Velocities from z = 2.08833         -> 1.91206
# Step: 17   / 50
# Positions  from z = 1.83126         -> 1.6824
# Velocities from z = 1.91206         -> 1.75482
# Step: 18   / 50
# Positions  from z = 1.6824          -> 1.54842
# Velocities from z = 1.75482         -> 1.6137
# Step: 19   / 50
# Positions  from z = 1.54842         -> 1.42718
# Velocities from z = 1.6137          -> 1.48633
# Step: 20   / 50
# Positions  from z = 1.42718         -> 1.31696
# Velocities from z = 1.48633         -> 1.37079
# Step: 21   / 50
# Positions  from z = 1.31696         -> 1.21631
# Velocities from z = 1.37079         -> 1.26552
# Step: 22   / 50
# Positions  from z = 1.21631         -> 1.12404
# Velocities from z = 1.26552         -> 1.1692
# Step: 23   / 50
# Positions  from z = 1.12404         -> 1.03915
# Velocities from z = 1.1692          -> 1.08073
# Step: 24   / 50
# Positions  from z = 1.03915         -> 0.960784
# Velocities from z = 1.08073         -> 0.9992
# Step: 25   / 50
# Positions  from z = 0.960784        -> 0.888218
# Velocities from z = 0.9992          -> 0.923817
# Step: 26   / 50
# Positions  from z = 0.888218        -> 0.82083
# Velocities from z = 0.923817        -> 0.853912
# Step: 27   / 50
# Positions  from z = 0.82083         -> 0.758087
# Velocities from z = 0.853912        -> 0.788909
# Step: 28   / 50
# Positions  from z = 0.758087        -> 0.699524
# Velocities from z = 0.788909        -> 0.72831
# Step: 29   / 50
# Positions  from z = 0.699524        -> 0.644737
# Velocities from z = 0.72831         -> 0.671682
# Step: 30   / 50
# Positions  from z = 0.644737        -> 0.593372
# Velocities from z = 0.671682        -> 0.618647
# Step: 31   / 50
# Positions  from z = 0.593372        -> 0.545117
# Velocities from z = 0.618647        -> 0.568874
# Step: 32   / 50
# Positions  from z = 0.545117        -> 0.4997
# Velocities from z = 0.568874        -> 0.52207
# Step: 33   / 50
# Positions  from z = 0.4997          -> 0.456876
# Velocities from z = 0.52207         -> 0.477978
# Step: 34   / 50
# Positions  from z = 0.456876        -> 0.416431
# Velocities from z = 0.477978        -> 0.436369
# Step: 35   / 50
# Positions  from z = 0.416431        -> 0.37817
# Velocities from z = 0.436369        -> 0.397038
# Step: 36   / 50
# Positions  from z = 0.37817         -> 0.341922
# Velocities from z = 0.397038        -> 0.359804
# Step: 37   / 50
# Positions  from z = 0.341922        -> 0.307531
# Velocities from z = 0.359804        -> 0.324503
# Step: 38   / 50
# Positions  from z = 0.307531        -> 0.27486
# Velocities from z = 0.324503        -> 0.290989
# Step: 39   / 50
# Positions  from z = 0.27486         -> 0.243781
# Velocities from z = 0.290989        -> 0.259129
# Step: 40   / 50
# Positions  from z = 0.243781        -> 0.214182
# Velocities from z = 0.259129        -> 0.228803
# Step: 41   / 50
# Positions  from z = 0.214182        -> 0.185958
# Velocities from z = 0.228803        -> 0.199904
# Step: 42   / 50
# Positions  from z = 0.185958        -> 0.159017
# Velocities from z = 0.199904        -> 0.172333
# Step: 43   / 50
# Positions  from z = 0.159017        -> 0.133273
# Velocities from z = 0.172333        -> 0.146
# Step: 44   / 50
# Positions  from z = 0.133273        -> 0.108647
# Velocities from z = 0.146           -> 0.120825
# Step: 45   / 50
# Positions  from z = 0.108647        -> 0.0850694
# Velocities from z = 0.120825        -> 0.0967317
# Step: 46   / 50
# Positions  from z = 0.0850694       -> 0.0624734
# Velocities from z = 0.0967317       -> 0.0736526
# Step: 47   / 50
# Positions  from z = 0.0624734       -> 0.0407993
# Velocities from z = 0.0736526       -> 0.0515247
# Step: 48   / 50
# Positions  from z = 0.0407993       -> 0.0199918
# Velocities from z = 0.0515247       -> 0.0302905
# Step: 49   / 50
# Positions  from z = 0.0199918       -> 0
# Velocities from z = 0.0302905       -> 0.00989699
# Step: 50   / 50
# Positions  from z = 0               -> 0
# Velocities from z = 0.00989699      -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 50 Total steps taken: 0
# Positions from  z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# deltatime_pos = 7.6803          deltatime_vel = 5.85402
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000644847
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000133784
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4199627 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.6159 %% (min)
# #               50.4344 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4703.54         MB (min over tasks)
# # Current RSS: 4704.6          MB (max over tasks)
# # Peak RSS:    5629.43         MB (min over tasks)
# # Peak RSS:    5630.57         MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 50 Total steps taken: 1
# Positions from  z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# deltatime_pos = 3.4432          deltatime_vel = 4.71236
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00166291
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000268303
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4205099 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.4473 %% (min)
# #               50.5572 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4704.37         MB (min over tasks)
# # Current RSS: 4710.72         MB (max over tasks)
# # Peak RSS:    5630.23         MB (min over tasks)
# # Peak RSS:    5631.48         MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 50 Total steps taken: 2
# Positions from  z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# deltatime_pos = 2.06155         deltatime_vel = 2.56964
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00118346
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000337912
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4209022 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.2307 %% (min)
# #               50.7482 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4685.41         MB (min over tasks)
# # Current RSS: 4711.4          MB (max over tasks)
# # Peak RSS:    5631.14         MB (min over tasks)
# # Peak RSS:    5636.78         MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 50 Total steps taken: 3
# Positions from  z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# deltatime_pos = 1.40974         deltatime_vel = 1.6712
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00114867
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000805022
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4211100 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.0563 %% (min)
# #               50.9467 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4686.12         MB (min over tasks)
# # Current RSS: 4712.28         MB (max over tasks)
# # Peak RSS:    5631.93         MB (min over tasks)
# # Peak RSS:    5637.46         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 50 Total steps taken: 4
# Positions from  z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# deltatime_pos = 1.04154         deltatime_vel = 1.19656
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00145479
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.0012628
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4213009 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.8743 %% (min)
# #               51.1368 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4687.27         MB (min over tasks)
# # Current RSS: 4713.04         MB (max over tasks)
# # Peak RSS:    5632.73         MB (min over tasks)
# # Peak RSS:    5638.33         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 50 Total steps taken: 5
# Positions from  z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# deltatime_pos = 0.80954         deltatime_vel = 0.91028
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00201688
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00210211
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4215119 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.6954 %% (min)
# #               51.3227 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4688.24         MB (min over tasks)
# # Current RSS: 4713.81         MB (max over tasks)
# # Peak RSS:    5633.51         MB (min over tasks)
# # Peak RSS:    5639.09         MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 50 Total steps taken: 6
# Positions from  z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# deltatime_pos = 0.652177        deltatime_vel = 0.722011
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.002385
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00272573
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4217954 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.5337 %% (min)
# #               51.5267 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4688.79         MB (min over tasks)
# # Current RSS: 4714.57         MB (max over tasks)
# # Peak RSS:    5634.18         MB (min over tasks)
# # Peak RSS:    5639.86         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 50 Total steps taken: 7
# Positions from  z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# deltatime_pos = 0.53957         deltatime_vel = 0.590331
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00268672
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00320352
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4221157 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.3817 %% (min)
# #               51.7259 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4689.57         MB (min over tasks)
# # Current RSS: 4715.33         MB (max over tasks)
# # Peak RSS:    5635.05         MB (min over tasks)
# # Peak RSS:    5640.62         MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 50 Total steps taken: 8
# Positions from  z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# deltatime_pos = 0.455656        deltatime_vel = 0.493954
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# ...
#  Time (sec): 1077.58       Memory: 943.997       (MB)
#  Time (sec): 1077.77       Memory: 1870.05       (MB)
#  Time (sec): 1086.43       Memory: 2796.09       (MB)
#  Time (sec): 1105          Memory: 3722.14       (MB)
#  Time (sec): 1105.59       Memory: 4648.19       (MB)
#  Time (sec): 1106.22       Memory: 5574.24       (MB)
#  Time (sec): 1122.77       Memory: 4648.19       (MB)
#  Time (sec): 1125.64       Memory: 3722.14       (MB)
#  Time (sec): 1126.04       Memory: 2796.09       (MB)
#  Time (sec): 1126.24       Memory: 1870.05       (MB)
#  Time (sec): 1126.4        Memory: 943.997       (MB)
#  Time (sec): 1126.58       Memory: 1870.05       (MB)
#  Time (sec): 1135.23       Memory: 2796.09       (MB)
#  Time (sec): 1153.19       Memory: 3722.14       (MB)
#  Time (sec): 1153.97       Memory: 4648.19       (MB)
#  Time (sec): 1154.54       Memory: 5574.24       (MB)
#  Time (sec): 1171.25       Memory: 4648.19       (MB)
#  Time (sec): 1174.06       Memory: 3722.14       (MB)
#  Time (sec): 1174.47       Memory: 2796.09       (MB)
#  Time (sec): 1174.68       Memory: 1870.05       (MB)
#  Time (sec): 1174.85       Memory: 943.997       (MB)
#  Time (sec): 1175.03       Memory: 1870.05       (MB)
#  Time (sec): 1183.72       Memory: 2796.09       (MB)
#  Time (sec): 1995.86       Memory: 4648.19       (MB)
#  Time (sec): 1998.72       Memory: 3722.14       (MB)
#  Time (sec): 1999.13       Memory: 2796.09       (MB)
#  Time (sec): 1999.33       Memory: 1870.05       (MB)
#  Time (sec): 1999.5        Memory: 943.997       (MB)
#  Time (sec): 1999.68       Memory: 1870.05       (MB)
#  Time (sec): 2008.39       Memory: 2796.09       (MB)
#  Time (sec): 2026.22       Memory: 3722.14       (MB)
#  Time (sec): 2027.13       Memory: 4648.19       (MB)
#  Time (sec): 2027.73       Memory: 5574.24       (MB)
#  Time (sec): 2044.5        Memory: 4648.19       (MB)
#  Time (sec): 2047.31       Memory: 3722.14       (MB)
#  Time (sec): 2047.71       Memory: 2796.09       (MB)
#  Time (sec): 2047.92       Memory: 1870.05       (MB)
#  Time (sec): 2048.08       Memory: 943.997       (MB)
#  Time (sec): 2048.26       Memory: 1870.05       (MB)
#  Time (sec): 2056.93       Memory: 2796.09       (MB)
#  Time (sec): 2075.05       Memory: 3722.14       (MB)
#  Time (sec): 2075.78       Memory: 4648.19       (MB)
#  Time (sec): 2076.43       Memory: 5574.24       (MB)
#  Time (sec): 2092.99       Memory: 4648.19       (MB)
#  Time (sec): 2095.8        Memory: 3722.14       (MB)
#  Time (sec): 2096.21       Memory: 2796.09       (MB)
#  Time (sec): 2096.42       Memory: 1870.05       (MB)
#  Time (sec): 2096.58       Memory: 943.997       (MB)
#  Time (sec): 2096.76       Memory: 1870.05       (MB)
#  Time (sec): 2105.45       Memory: 2796.09       (MB)
#  Time (sec): 2123.48       Memory: 3722.14       (MB)
#  Time (sec): 2124.18       Memory: 4648.19       (MB)
#  Time (sec): 2124.71       Memory: 5574.24       (MB)
#  Time (sec): 2141.57       Memory: 4648.19       (MB)
#  Time (sec): 2144.42       Memory: 3722.14       (MB)
#  Time (sec): 2144.84       Memory: 2796.09       (MB)
#  Time (sec): 2145.05       Memory: 1870.05       (MB)
#  Time (sec): 2145.21       Memory: 943.997       (MB)
#  Time (sec): 2145.39       Memory: 1870.05       (MB)
#  Time (sec): 2154.12       Memory: 2796.09       (MB)
#  Time (sec): 2172.05       Memory: 3722.14       (MB)
#  Time (sec): 2172.91       Memory: 4648.19       (MB)
#  Time (sec): 2173.52       Memory: 5574.24       (MB)
#  Time (sec): 2190.16       Memory: 4648.19       (MB)
#  Time (sec): 2193.1        Memory: 3722.14       (MB)
#  Time (sec): 2193.51       Memory: 2796.09       (MB)
#  Time (sec): 2193.71       Memory: 1870.05       (MB)
#  Time (sec): 2193.87       Memory: 943.997       (MB)
#  Time (sec): 2194.06       Memory: 1870.05       (MB)
#  Time (sec): 2202.8        Memory: 2796.09       (MB)
#  Time (sec): 2221.1        Memory: 3722.14       (MB)
#  Time (sec): 2221.71       Memory: 4648.19       (MB)
#  Time (sec): 2222.35       Memory: 5574.24       (MB)
#  Time (sec): 2238.79       Memory: 4648.19       (MB)
#  Time (sec): 2241.67       Memory: 3722.14       (MB)
#  Time (sec): 2242.07       Memory: 2796.09       (MB)
#  Time (sec): 2242.28       Memory: 1870.05       (MB)
#  Time (sec): 2242.44       Memory: 943.997       (MB)
#  Time (sec): 2242.62       Memory: 1870.05       (MB)
#  Time (sec): 2251.29       Memory: 2796.09       (MB)
#  Time (sec): 2269.55       Memory: 3722.14       (MB)
#  Time (sec): 2270.17       Memory: 4648.19       (MB)
#  Time (sec): 2270.82       Memory: 5574.24       (MB)
#  Time (sec): 2287.5        Memory: 4648.19       (MB)
#  Time (sec): 2290.24       Memory: 3722.14       (MB)
#  Time (sec): 2290.64       Memory: 2796.09       (MB)
#  Time (sec): 2290.85       Memory: 1870.05       (MB)
#  Time (sec): 2291.01       Memory: 943.997       (MB)
#  Time (sec): 2291.19       Memory: 1870.05       (MB)
#  Time (sec): 2299.92       Memory: 2796.09       (MB)
#  Time (sec): 2317.88       Memory: 3722.14       (MB)
#  Time (sec): 2318.61       Memory: 4648.19       (MB)
#  Time (sec): 2319.27       Memory: 5574.24       (MB)
#  Time (sec): 2335.81       Memory: 4648.19       (MB)
#  Time (sec): 2338.7        Memory: 3722.14       (MB)
#  Time (sec): 2339.1        Memory: 2796.09       (MB)
#  Time (sec): 2339.31       Memory: 1870.05       (MB)
#  Time (sec): 2339.47       Memory: 943.997       (MB)
#  Time (sec): 2339.65       Memory: 1870.05       (MB)
#  Time (sec): 2348.34       Memory: 2796.09       (MB)
#  Time (sec): 2366.49       Memory: 3722.14       (MB)
#  Time (sec): 2367.17       Memory: 4648.19       (MB)
#  Time (sec): 2367.8        Memory: 5574.24       (MB)
#  Time (sec): 2384.53       Memory: 4648.19       (MB)
#  Time (sec): 2387.38       Memory: 3722.14       (MB)
#  Time (sec): 2387.77       Memory: 2796.09       (MB)
#  Time (sec): 2387.98       Memory: 1870.05       (MB)
#  Time (sec): 2388.14       Memory: 943.997       (MB)
#  Time (sec): 2388.32       Memory: 1870.05       (MB)
#  Time (sec): 2397.03       Memory: 2796.09       (MB)
#  Time (sec): 2414.9        Memory: 3722.14       (MB)
#  Time (sec): 2415.68       Memory: 4648.19       (MB)
#  Time (sec): 2416.24       Memory: 5574.24       (MB)
#  Time (sec): 2433.03       Memory: 4648.19       (MB)
#  Time (sec): 2435.83       Memory: 3722.14       (MB)
#  Time (sec): 2436.25       Memory: 2796.09       (MB)
#  Time (sec): 2436.45       Memory: 1870.05       (MB)
#  Time (sec): 2436.61       Memory: 943.997       (MB)
#  Time (sec): 2436.79       Memory: 1870.05       (MB)
#  Time (sec): 2445.53       Memory: 2796.09       (MB)
#  Time (sec): 2463.71       Memory: 3722.14       (MB)
#  Time (sec): 2464.29       Memory: 4648.19       (MB)
#  Time (sec): 2464.84       Memory: 5574.24       (MB)
#  Time (sec): 2481.59       Memory: 4648.19       (MB)
#  Time (sec): 2484.04       Memory: 3722.14       (MB)
#  Time (sec): 2484.45       Memory: 2796.09       (MB)
#  Time (sec): 2484.67       Memory: 1870.05       (MB)
#  Time (sec): 2484.83       Memory: 943.997       (MB)
#  Time (sec): 2485.76       Memory: 1926.74       (MB)
#  Time (sec): 2491.19       Memory: 2909.49       (MB)
#  Time (sec): 2507.08       Memory: 1926.74       (MB)
#  Time (sec): 2510.13       Memory: 943.997       (MB)
#
# #=====================================================
# 0

# %%
"""Create P(k) phasepair"""

os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_ESS-C_phasepair_8.lua")
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-3]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-3]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-3]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-3]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-3]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-3]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-3]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-3]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-3]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-3]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-3]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-3]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-3]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-3]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-3]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-3]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-3]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-3]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-3]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-3]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-3]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-3]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-3]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-3]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-3]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-3]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-3]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-3]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-3]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-3]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-3]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-3]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 62 elements:
# #=====================================================
#   HiCOLA_expansion_filename      : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_expansion.txt
#   HiCOLA_preforce_filename       : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_force.txt
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.092e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.238611
#   cosmology_OmegaLambda          : 0.720179
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.0411296
#   cosmology_TCMB_kelvin          : 2.74107
#   cosmology_h                    : 0.7307
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : HiCOLA
#   cosmology_ns                   : 0.9626
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : HiCOLA
#   gravity_model_HiCOLA_smoothing_filter : gaussian
#   gravity_model_HiCOLA_smoothing_scale_over_boxsize : 0.0075
#   gravity_model_screening        : true
#   gravity_model_screening_enforce_largescale_linear : true
#   gravity_model_screening_linear_scale_hmpc : 0.2
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : true
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_8
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_ESS-C_phasepair_8
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              50 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [HiCOLA]
# # Omegab      : 0.0411296
# # OmegaM      : 0.279741
# # OmegaMNu    : 0
# # OmegaCDM    : 0.238611
# # OmegaLambda : 0.720179
# # OmegaR      : 4.73844e-05
# # OmegaNu     : 3.27791e-05
# # OmegaRtot   : 8.01635e-05
# # OmegaK      : 0
# # h           : 0.7307
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.74107 K
# # Tnu         : 1.96394 K
# # As          : 2.092e-09
# # ns          : 0.9626
# # kpivot      : 0.05 1/Mpc
# # HiCOLA_expansion_filename     : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_expansion.txt
# #=====================================================
#
# #=====================================================
# # GravityModel is [HiCOLA] and has the cosmology: [HiCOLA]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# # HiCOLA_preforce_filename : /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_Output/ESS-C_run_ESS-C_force.txt
# # Screening method : true
# # Enforce correct linear evolution : true
# # Scale for which we enforce this  : 0.2 h/Mpc
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_ESS-C_phasepair_8
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : true
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 50
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_8
#
# #=====================================================
# # Create initial conditions
# #=====================================================
#
# #=====================================================
# # Reading power-spectrum from ascii file [/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat]
# # The P(k) is at the redshift: 49
# # Using growth factors we scaled it to redshift: 49
# # Found n: 499 lines in file (sample of it below):
# #=====================================================
# # k (h/Mpc)      P(k,zini)  (Mpc/h)^3    T(k,zini)  (Mpc)^2
# 0.00101863      3.17809         475864
# 0.00251653      7.10803         460496
# 0.00621709      13.9011         416705
# 0.0153593       19.7767         321613
# 0.0379453       14.5802         178686
# 0.0937441       6.0765          74642.7
# 0.231595        1.51166         24090.2
# 0.572157        0.250251        6342.4
# 1.41352         0.0324636       1478.14
# 3.4921          0.00358914      318.028
# 8.62724         0.00035657      64.8626
#
# #=====================================================
# # Testing splines:
# #=====================================================
# k =  0.01: P(k,zini) = 17.7301 (Mpc/h)^3
# k =  0.10: P(k,zini) = 5.63202 (Mpc/h)^3
# k =  1.00: P(k,zini) = 0.0725552 (Mpc/h)^3
# k = 10.00: P(k,zini) = 0.000242701 (Mpc/h)^3
#
# #=====================================================
# # Sigma(R = 8 Mpc/h, z = 0.0 ) : 0.976588
# #=====================================================
#
# #=====================================================
# #
# #                .___  _________
# #                |   | \_   ___ \
# #                |   | /    \  \/
# #                |   | \     \____
# #                |___|  \______  /
# #                              \/
# #
# # Generating initial conditions for N-body
# # Order in LPT = 2
# # The boxsize is 400 comoving Mpc/h
# # The initial redshift zini = 49
# # Particle has [Position] x_code = x / Box (24 bytes)
# # Particle has [Velocity] v_code = a^2 dxdt / (H0 Box) (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Total size of particle is 104 bytes
# # We will make 512^3 particles
# # Plus a buffer with room for 100%% more particles
# # We will allocate ~872.415 MB per task for the particles
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4194304 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               50 %% (min)
# #               50 %% (max) filled across tasks
# #
# #=====================================================
#
# Storing unique ID in particle
# Storing Lagrangian position q in particle
# Adding 1LPT position to particle
# Adding 1LPT velocity to particle
# Storing 1LPT displacment field in particle
# Maximum 1LPT displacements: 0.886038 Mpc/h
# Maximum 1LPT velocity: 330.56 km/s peculiar
# Adding 2LPT position to particle
# Adding 2LPT velocity to particle
# Storing 2LPT displacment field in particle
# Maximum 2LPT displacements: 0.0165882 Mpc/h
# Maximum 2LPT velocity: 12.4101 km/s peculiar
# Storing initial 2LPT potential
#
# #=====================================================
# # The time-steps and outputs we plan to take
# #=====================================================
#
# Next output z = 0 nsteps: 50
# Step: 0    / 50
# Positions  from z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# Step: 1    / 50
# Positions  from z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# Step: 2    / 50
# Positions  from z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# Step: 3    / 50
# Positions  from z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# Step: 4    / 50
# Positions  from z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# Step: 5    / 50
# Positions  from z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# Step: 6    / 50
# Positions  from z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# Step: 7    / 50
# Positions  from z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# Step: 8    / 50
# Positions  from z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# Step: 9    / 50
# Positions  from z = 4.09165         -> 3.62963
# Velocities from z = 4.35906         -> 3.84966
# Step: 10   / 50
# Positions  from z = 3.62963         -> 3.24448
# Velocities from z = 3.84966         -> 3.4287
# Step: 11   / 50
# Positions  from z = 3.24448         -> 2.9185
# Velocities from z = 3.4287          -> 3.07498
# Step: 12   / 50
# Positions  from z = 2.9185          -> 2.63901
# Velocities from z = 3.07498         -> 2.77358
# Step: 13   / 50
# Positions  from z = 2.63901         -> 2.39674
# Velocities from z = 2.77358         -> 2.5137
# Step: 14   / 50
# Positions  from z = 2.39674         -> 2.18471
# Velocities from z = 2.5137          -> 2.28731
# Step: 15   / 50
# Positions  from z = 2.18471         -> 1.9976
# Velocities from z = 2.28731         -> 2.08833
# Step: 16   / 50
# Positions  from z = 1.9976          -> 1.83126
# Velocities from z = 2.08833         -> 1.91206
# Step: 17   / 50
# Positions  from z = 1.83126         -> 1.6824
# Velocities from z = 1.91206         -> 1.75482
# Step: 18   / 50
# Positions  from z = 1.6824          -> 1.54842
# Velocities from z = 1.75482         -> 1.6137
# Step: 19   / 50
# Positions  from z = 1.54842         -> 1.42718
# Velocities from z = 1.6137          -> 1.48633
# Step: 20   / 50
# Positions  from z = 1.42718         -> 1.31696
# Velocities from z = 1.48633         -> 1.37079
# Step: 21   / 50
# Positions  from z = 1.31696         -> 1.21631
# Velocities from z = 1.37079         -> 1.26552
# Step: 22   / 50
# Positions  from z = 1.21631         -> 1.12404
# Velocities from z = 1.26552         -> 1.1692
# Step: 23   / 50
# Positions  from z = 1.12404         -> 1.03915
# Velocities from z = 1.1692          -> 1.08073
# Step: 24   / 50
# Positions  from z = 1.03915         -> 0.960784
# Velocities from z = 1.08073         -> 0.9992
# Step: 25   / 50
# Positions  from z = 0.960784        -> 0.888218
# Velocities from z = 0.9992          -> 0.923817
# Step: 26   / 50
# Positions  from z = 0.888218        -> 0.82083
# Velocities from z = 0.923817        -> 0.853912
# Step: 27   / 50
# Positions  from z = 0.82083         -> 0.758087
# Velocities from z = 0.853912        -> 0.788909
# Step: 28   / 50
# Positions  from z = 0.758087        -> 0.699524
# Velocities from z = 0.788909        -> 0.72831
# Step: 29   / 50
# Positions  from z = 0.699524        -> 0.644737
# Velocities from z = 0.72831         -> 0.671682
# Step: 30   / 50
# Positions  from z = 0.644737        -> 0.593372
# Velocities from z = 0.671682        -> 0.618647
# Step: 31   / 50
# Positions  from z = 0.593372        -> 0.545117
# Velocities from z = 0.618647        -> 0.568874
# Step: 32   / 50
# Positions  from z = 0.545117        -> 0.4997
# Velocities from z = 0.568874        -> 0.52207
# Step: 33   / 50
# Positions  from z = 0.4997          -> 0.456876
# Velocities from z = 0.52207         -> 0.477978
# Step: 34   / 50
# Positions  from z = 0.456876        -> 0.416431
# Velocities from z = 0.477978        -> 0.436369
# Step: 35   / 50
# Positions  from z = 0.416431        -> 0.37817
# Velocities from z = 0.436369        -> 0.397038
# Step: 36   / 50
# Positions  from z = 0.37817         -> 0.341922
# Velocities from z = 0.397038        -> 0.359804
# Step: 37   / 50
# Positions  from z = 0.341922        -> 0.307531
# Velocities from z = 0.359804        -> 0.324503
# Step: 38   / 50
# Positions  from z = 0.307531        -> 0.27486
# Velocities from z = 0.324503        -> 0.290989
# Step: 39   / 50
# Positions  from z = 0.27486         -> 0.243781
# Velocities from z = 0.290989        -> 0.259129
# Step: 40   / 50
# Positions  from z = 0.243781        -> 0.214182
# Velocities from z = 0.259129        -> 0.228803
# Step: 41   / 50
# Positions  from z = 0.214182        -> 0.185958
# Velocities from z = 0.228803        -> 0.199904
# Step: 42   / 50
# Positions  from z = 0.185958        -> 0.159017
# Velocities from z = 0.199904        -> 0.172333
# Step: 43   / 50
# Positions  from z = 0.159017        -> 0.133273
# Velocities from z = 0.172333        -> 0.146
# Step: 44   / 50
# Positions  from z = 0.133273        -> 0.108647
# Velocities from z = 0.146           -> 0.120825
# Step: 45   / 50
# Positions  from z = 0.108647        -> 0.0850694
# Velocities from z = 0.120825        -> 0.0967317
# Step: 46   / 50
# Positions  from z = 0.0850694       -> 0.0624734
# Velocities from z = 0.0967317       -> 0.0736526
# Step: 47   / 50
# Positions  from z = 0.0624734       -> 0.0407993
# Velocities from z = 0.0736526       -> 0.0515247
# Step: 48   / 50
# Positions  from z = 0.0407993       -> 0.0199918
# Velocities from z = 0.0515247       -> 0.0302905
# Step: 49   / 50
# Positions  from z = 0.0199918       -> 0
# Velocities from z = 0.0302905       -> 0.00989699
# Step: 50   / 50
# Positions  from z = 0               -> 0
# Velocities from z = 0.00989699      -> 0
#
#
# #=====================================================
# # Starting main time-stepping loop
# #=====================================================
#
#
# Taking substep: 0 / 50 Total steps taken: 0
# Positions from  z = 49              -> 24.2525
# Velocities from z = 49              -> 32.557
# deltatime_pos = 7.6803          deltatime_vel = 5.85402
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# At a= 0.02 chi/delta=0.626359 coupling=0.000906134
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.000635601
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000142435
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4188442 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.5738 %% (min)
# #               50.3744 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4704.63         MB (min over tasks)
# # Current RSS: 4705.16         MB (max over tasks)
# # Peak RSS:    5630.67         MB (min over tasks)
# # Peak RSS:    5631.21         MB (max over tasks)
# #=====================================================
#
# Taking substep: 1 / 50 Total steps taken: 1
# Positions from  z = 24.2525         -> 15.8919
# Velocities from z = 32.557          -> 19.2429
# deltatime_pos = 3.4432          deltatime_vel = 4.71236
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# At a= 0.0396 chi/delta=0.633175 coupling=0.000938287
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00166626
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000242133
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4182455 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.4263 %% (min)
# #               50.5767 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4705.42         MB (min over tasks)
# # Current RSS: 4711.07         MB (max over tasks)
# # Peak RSS:    5631.48         MB (min over tasks)
# # Peak RSS:    5631.98         MB (max over tasks)
# #=====================================================
#
# Taking substep: 2 / 50 Total steps taken: 2
# Positions from  z = 15.8919         -> 11.6904
# Velocities from z = 19.2429         -> 13.4928
# deltatime_pos = 2.06155         deltatime_vel = 2.56964
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# At a= 0.0592 chi/delta=0.63589 coupling=0.00103932
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00119093
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000344533
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4179053 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.2338 %% (min)
# #               50.7955 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4685.67         MB (min over tasks)
# # Current RSS: 4711.96         MB (max over tasks)
# # Peak RSS:    5632.24         MB (min over tasks)
# # Peak RSS:    5637.12         MB (max over tasks)
# #=====================================================
#
# Taking substep: 3 / 50 Total steps taken: 3
# Positions from  z = 11.6904         -> 9.1626
# Velocities from z = 13.4928         -> 10.2867
# deltatime_pos = 1.40974         deltatime_vel = 1.6712
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# At a= 0.0788 chi/delta=0.637242 coupling=0.00123596
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00111989
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.000704019
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4174927 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               49.0216 %% (min)
# #               51.0276 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4686.66         MB (min over tasks)
# # Current RSS: 4712.7          MB (max over tasks)
# # Peak RSS:    5633            MB (min over tasks)
# # Peak RSS:    5638.01         MB (max over tasks)
# #=====================================================
#
# Taking substep: 4 / 50 Total steps taken: 4
# Positions from  z = 9.1626          -> 7.47458
# Velocities from z = 10.2867         -> 8.24214
# deltatime_pos = 1.04154         deltatime_vel = 1.19656
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# At a= 0.0984 chi/delta=0.637767 coupling=0.00155918
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00134573
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00122545
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4172179 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.8207 %% (min)
# #               51.2411 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4687.45         MB (min over tasks)
# # Current RSS: 4713.44         MB (max over tasks)
# # Peak RSS:    5633.77         MB (min over tasks)
# # Peak RSS:    5638.75         MB (max over tasks)
# #=====================================================
#
# Taking substep: 5 / 50 Total steps taken: 5
# Positions from  z = 7.47458         -> 6.26744
# Velocities from z = 8.24214         -> 6.82473
# deltatime_pos = 0.80954         deltatime_vel = 0.91028
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# At a= 0.118 chi/delta=0.63782 coupling=0.00204022
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00190465
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.0020953
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4168880 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.6348 %% (min)
# #               51.4392 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4688.51         MB (min over tasks)
# # Current RSS: 4714.21         MB (max over tasks)
# # Peak RSS:    5634.53         MB (min over tasks)
# # Peak RSS:    5639.5          MB (max over tasks)
# #=====================================================
#
# Taking substep: 6 / 50 Total steps taken: 6
# Positions from  z = 6.26744         -> 5.36132
# Velocities from z = 6.82473         -> 5.78426
# deltatime_pos = 0.652177        deltatime_vel = 0.722011
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# At a= 0.1376 chi/delta=0.63771 coupling=0.00271143
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.0021512
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00259121
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4166810 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.4287 %% (min)
# #               51.6603 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4689.51         MB (min over tasks)
# # Current RSS: 4714.95         MB (max over tasks)
# # Peak RSS:    5635.28         MB (min over tasks)
# # Peak RSS:    5640.26         MB (max over tasks)
# #=====================================================
#
# Taking substep: 7 / 50 Total steps taken: 7
# Positions from  z = 5.36132         -> 4.65611
# Velocities from z = 5.78426         -> 4.98802
# deltatime_pos = 0.53957         deltatime_vel = 0.590331
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# At a= 0.1572 chi/delta=0.637703 coupling=0.0036044
# Combining screened solution with linear solution
# We use linear solution for k < 0.2 h/Mpc
# [Kick] Max delta_vel * delta_time : 0.00237009
# [Kick] + [Drift] COLA 2LPT
# [Drift] Max displacement: 0.00267205
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Info about MPIParticles. Dimension of particles is 3
# # We have allocated 872.415 MB (mean)
# #                   872.415 MB (min)
# #                   872.415 MB (max)
# # Total particles across all tasks is 134217728
# # Task 0 has 4163003 parts. Capacity: 8388608
# # The buffer is 50 %% (mean)
# #               48.2263 %% (min)
# #               51.8653 %% (max) filled across tasks
# #
# #=====================================================
#
# #=====================================================
# # System memory use (resident set size):
# # Current RSS: 4690.27         MB (min over tasks)
# # Current RSS: 4715.53         MB (max over tasks)
# # Peak RSS:    5636.07         MB (min over tasks)
# # Peak RSS:    5641            MB (max over tasks)
# #=====================================================
#
# Taking substep: 8 / 50 Total steps taken: 8
# Positions from  z = 4.65611         -> 4.09165
# Velocities from z = 4.98802         -> 4.35906
# deltatime_pos = 0.455656        deltatime_vel = 0.493954
# Adding particles (baryons+CDM) to the densityfield
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# At a= 0.1768 chi/delta=0.637984 coupling=0.00475091
# ...
#  Time (sec): 1099.81       Memory: 943.997       (MB)
#  Time (sec): 1099.97       Memory: 1870.05       (MB)
#  Time (sec): 1108.61       Memory: 2796.09       (MB)
#  Time (sec): 1126.81       Memory: 3722.14       (MB)
#  Time (sec): 1127.37       Memory: 4648.19       (MB)
#  Time (sec): 1128.19       Memory: 5574.24       (MB)
#  Time (sec): 1146.03       Memory: 4648.19       (MB)
#  Time (sec): 1148.9        Memory: 3722.14       (MB)
#  Time (sec): 1149.3        Memory: 2796.09       (MB)
#  Time (sec): 1149.59       Memory: 1870.05       (MB)
#  Time (sec): 1149.75       Memory: 943.997       (MB)
#  Time (sec): 1149.92       Memory: 1870.05       (MB)
#  Time (sec): 1158.54       Memory: 2796.09       (MB)
#  Time (sec): 1176.89       Memory: 3722.14       (MB)
#  Time (sec): 1177.47       Memory: 4648.19       (MB)
#  Time (sec): 1178.26       Memory: 5574.24       (MB)
#  Time (sec): 1196.21       Memory: 4648.19       (MB)
#  Time (sec): 1199.1        Memory: 3722.14       (MB)
#  Time (sec): 1199.54       Memory: 2796.09       (MB)
#  Time (sec): 1199.84       Memory: 1870.05       (MB)
#  Time (sec): 1200          Memory: 943.997       (MB)
#  Time (sec): 1200.17       Memory: 1870.05       (MB)
#  Time (sec): 1208.85       Memory: 2796.09       (MB)
#  Time (sec): 1749.99       Memory: 1870.05       (MB)
#  Time (sec): 1758.67       Memory: 2796.09       (MB)
#  Time (sec): 1776.63       Memory: 3722.14       (MB)
#  Time (sec): 1777.32       Memory: 4648.19       (MB)
#  Time (sec): 1778.11       Memory: 5574.24       (MB)
#  Time (sec): 1795.87       Memory: 4648.19       (MB)
#  Time (sec): 1798.86       Memory: 3722.14       (MB)
#  Time (sec): 1799.25       Memory: 2796.09       (MB)
#  Time (sec): 1799.56       Memory: 1870.05       (MB)
#  Time (sec): 1799.72       Memory: 943.997       (MB)
#  Time (sec): 1799.88       Memory: 1870.05       (MB)
#  Time (sec): 1808.44       Memory: 2796.09       (MB)
#  Time (sec): 1826.64       Memory: 3722.14       (MB)
#  Time (sec): 1827.23       Memory: 4648.19       (MB)
#  Time (sec): 1828          Memory: 5574.24       (MB)
#  Time (sec): 1845.8        Memory: 4648.19       (MB)
#  Time (sec): 1848.64       Memory: 3722.14       (MB)
#  Time (sec): 1849.04       Memory: 2796.09       (MB)
#  Time (sec): 1849.34       Memory: 1870.05       (MB)
#  Time (sec): 1849.5        Memory: 943.997       (MB)
#  Time (sec): 1849.66       Memory: 1870.05       (MB)
#  Time (sec): 1858.31       Memory: 2796.09       (MB)
#  Time (sec): 1876.18       Memory: 3722.14       (MB)
#  Time (sec): 1876.95       Memory: 4648.19       (MB)
#  Time (sec): 1877.72       Memory: 5574.24       (MB)
#  Time (sec): 1895.47       Memory: 4648.19       (MB)
#  Time (sec): 1898.36       Memory: 3722.14       (MB)
#  Time (sec): 1898.78       Memory: 2796.09       (MB)
#  Time (sec): 1899.1        Memory: 1870.05       (MB)
#  Time (sec): 1899.26       Memory: 943.997       (MB)
#  Time (sec): 1899.42       Memory: 1870.05       (MB)
#  Time (sec): 1908.04       Memory: 2796.09       (MB)
#  Time (sec): 1926.02       Memory: 3722.14       (MB)
#  Time (sec): 1926.63       Memory: 4648.19       (MB)
#  Time (sec): 1927.42       Memory: 5574.24       (MB)
#  Time (sec): 1945.17       Memory: 4648.19       (MB)
#  Time (sec): 1948.1        Memory: 3722.14       (MB)
#  Time (sec): 1948.51       Memory: 2796.09       (MB)
#  Time (sec): 1948.82       Memory: 1870.05       (MB)
#  Time (sec): 1948.99       Memory: 943.997       (MB)
#  Time (sec): 1949.15       Memory: 1870.05       (MB)
#  Time (sec): 1957.72       Memory: 2796.09       (MB)
#  Time (sec): 1975.64       Memory: 3722.14       (MB)
#  Time (sec): 1976.31       Memory: 4648.19       (MB)
#  Time (sec): 1977.09       Memory: 5574.24       (MB)
#  Time (sec): 1994.88       Memory: 4648.19       (MB)
#  Time (sec): 1997.78       Memory: 3722.14       (MB)
#  Time (sec): 1998.18       Memory: 2796.09       (MB)
#  Time (sec): 1998.49       Memory: 1870.05       (MB)
#  Time (sec): 1998.65       Memory: 943.997       (MB)
#  Time (sec): 1998.81       Memory: 1870.05       (MB)
#  Time (sec): 2007.42       Memory: 2796.09       (MB)
#  Time (sec): 2025.4        Memory: 3722.14       (MB)
#  Time (sec): 2026.01       Memory: 4648.19       (MB)
#  Time (sec): 2026.8        Memory: 5574.24       (MB)
#  Time (sec): 2044.6        Memory: 4648.19       (MB)
#  Time (sec): 2047.56       Memory: 3722.14       (MB)
#  Time (sec): 2047.97       Memory: 2796.09       (MB)
#  Time (sec): 2048.28       Memory: 1870.05       (MB)
#  Time (sec): 2048.44       Memory: 943.997       (MB)
#  Time (sec): 2048.61       Memory: 1870.05       (MB)
#  Time (sec): 2057.28       Memory: 2796.09       (MB)
#  Time (sec): 2075.39       Memory: 3722.14       (MB)
#  Time (sec): 2075.95       Memory: 4648.19       (MB)
#  Time (sec): 2076.73       Memory: 5574.24       (MB)
#  Time (sec): 2094.54       Memory: 4648.19       (MB)
#  Time (sec): 2097.51       Memory: 3722.14       (MB)
#  Time (sec): 2097.9        Memory: 2796.09       (MB)
#  Time (sec): 2098.2        Memory: 1870.05       (MB)
#  Time (sec): 2098.37       Memory: 943.997       (MB)
#  Time (sec): 2098.53       Memory: 1870.05       (MB)
#  Time (sec): 2107.17       Memory: 2796.09       (MB)
#  Time (sec): 2125.15       Memory: 3722.14       (MB)
#  Time (sec): 2125.85       Memory: 4648.19       (MB)
#  Time (sec): 2126.64       Memory: 5574.24       (MB)
#  Time (sec): 2144.47       Memory: 4648.19       (MB)
#  Time (sec): 2147.41       Memory: 3722.14       (MB)
#  Time (sec): 2147.82       Memory: 2796.09       (MB)
#  Time (sec): 2148.12       Memory: 1870.05       (MB)
#  Time (sec): 2148.28       Memory: 943.997       (MB)
#  Time (sec): 2148.44       Memory: 1870.05       (MB)
#  Time (sec): 2157.09       Memory: 2796.09       (MB)
#  Time (sec): 2175.04       Memory: 3722.14       (MB)
#  Time (sec): 2175.68       Memory: 4648.19       (MB)
#  Time (sec): 2176.47       Memory: 5574.24       (MB)
#  Time (sec): 2194.2        Memory: 4648.19       (MB)
#  Time (sec): 2197.14       Memory: 3722.14       (MB)
#  Time (sec): 2197.55       Memory: 2796.09       (MB)
#  Time (sec): 2197.86       Memory: 1870.05       (MB)
#  Time (sec): 2198.02       Memory: 943.997       (MB)
#  Time (sec): 2198.18       Memory: 1870.05       (MB)
#  Time (sec): 2206.83       Memory: 2796.09       (MB)
#  Time (sec): 2224.56       Memory: 3722.14       (MB)
#  Time (sec): 2225.38       Memory: 4648.19       (MB)
#  Time (sec): 2226.09       Memory: 5574.24       (MB)
#  Time (sec): 2243.99       Memory: 4648.19       (MB)
#  Time (sec): 2246.91       Memory: 3722.14       (MB)
#  Time (sec): 2247.33       Memory: 2796.09       (MB)
#  Time (sec): 2247.65       Memory: 1870.05       (MB)
#  Time (sec): 2247.81       Memory: 943.997       (MB)
#  Time (sec): 2247.97       Memory: 1870.05       (MB)
#  Time (sec): 2256.57       Memory: 2796.09       (MB)
#  Time (sec): 2274.61       Memory: 3722.14       (MB)
#  Time (sec): 2275.29       Memory: 4648.19       (MB)
#  Time (sec): 2276.1        Memory: 5574.24       (MB)
#  Time (sec): 2293.82       Memory: 4648.19       (MB)
#  Time (sec): 2296.78       Memory: 3722.14       (MB)
#  Time (sec): 2297.18       Memory: 2796.09       (MB)
#  Time (sec): 2297.47       Memory: 1870.05       (MB)
#  Time (sec): 2297.64       Memory: 943.997       (MB)
#  Time (sec): 2297.8        Memory: 1870.05       (MB)
#  Time (sec): 2306.42       Memory: 2796.09       (MB)
#  Time (sec): 2324.5        Memory: 3722.14       (MB)
#  Time (sec): 2325.09       Memory: 4648.19       (MB)
#  Time (sec): 2325.91       Memory: 5574.24       (MB)
#  Time (sec): 2343.69       Memory: 4648.19       (MB)
#  Time (sec): 2346.66       Memory: 3722.14       (MB)
#  Time (sec): 2347.07       Memory: 2796.09       (MB)
#  Time (sec): 2347.37       Memory: 1870.05       (MB)
#  Time (sec): 2347.54       Memory: 943.997       (MB)
#  Time (sec): 2347.7        Memory: 1870.05       (MB)
#  Time (sec): 2356.32       Memory: 2796.09       (MB)
#  Time (sec): 2374.41       Memory: 3722.14       (MB)
#  Time (sec): 2374.93       Memory: 4648.19       (MB)
#  Time (sec): 2375.74       Memory: 5574.24       (MB)
#  Time (sec): 2393.54       Memory: 4648.19       (MB)
#  Time (sec): 2396.54       Memory: 3722.14       (MB)
#  Time (sec): 2396.95       Memory: 2796.09       (MB)
#  Time (sec): 2397.25       Memory: 1870.05       (MB)
#  Time (sec): 2397.42       Memory: 943.997       (MB)
#  Time (sec): 2397.58       Memory: 1870.05       (MB)
#  Time (sec): 2406.17       Memory: 2796.09       (MB)
#  Time (sec): 2424.17       Memory: 3722.14       (MB)
#  Time (sec): 2424.85       Memory: 4648.19       (MB)
#  Time (sec): 2425.63       Memory: 5574.24       (MB)
#  Time (sec): 2443.35       Memory: 4648.19       (MB)
#  Time (sec): 2446.21       Memory: 3722.14       (MB)
#  Time (sec): 2446.62       Memory: 2796.09       (MB)
#  Time (sec): 2446.94       Memory: 1870.05       (MB)
#  Time (sec): 2447.09       Memory: 943.997       (MB)
#  Time (sec): 2447.25       Memory: 1870.05       (MB)
#  Time (sec): 2455.88       Memory: 2796.09       (MB)
#  Time (sec): 2474.09       Memory: 3722.14       (MB)
#  Time (sec): 2474.59       Memory: 4648.19       (MB)
#  Time (sec): 2475.41       Memory: 5574.24       (MB)
#  Time (sec): 2493          Memory: 4648.19       (MB)
#  Time (sec): 2495.9        Memory: 3722.14       (MB)
#  Time (sec): 2496.3        Memory: 2796.09       (MB)
#  Time (sec): 2496.61       Memory: 1870.05       (MB)
#  Time (sec): 2496.77       Memory: 943.997       (MB)
#  Time (sec): 2496.93       Memory: 1870.05       (MB)
#  Time (sec): 2505.57       Memory: 2796.09       (MB)
#  Time (sec): 2523.5        Memory: 3722.14       (MB)
#  Time (sec): 2524.22       Memory: 4648.19       (MB)
#  Time (sec): 2525.03       Memory: 5574.24       (MB)
#  Time (sec): 2542.74       Memory: 4648.19       (MB)
#  Time (sec): 2545.41       Memory: 3722.14       (MB)
#  Time (sec): 2545.84       Memory: 2796.09       (MB)
#  Time (sec): 2546.14       Memory: 1870.05       (MB)
#  Time (sec): 2546.3        Memory: 943.997       (MB)
#  Time (sec): 2547.53       Memory: 1926.74       (MB)
#  Time (sec): 2552.46       Memory: 2909.49       (MB)
#  Time (sec): 2568.09       Memory: 1926.74       (MB)
#  Time (sec): 2571.18       Memory: 943.997       (MB)
#
# #=====================================================
# 0

# %%
def rewriteluafile_GR(k, sample,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    wb = 0.02196
    wr = 4.28e-5
    #sample = Omega_m , n_s    , A_s ,h,  f_phi, EdS, k_1dS, g_31dS, k_2dS, g_32dS
    n_s = sample[1]
    A_s = sample[2]
    h = sample[3]
    wm = sample[0]*h**2

    f_phi = sample[4]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_GR_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_GR_{}"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "None"'+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "None"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_{}"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = false'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
def rewriteluafile_GR_phasepair(k, sample,boxsize,n_particles,n_mesh):
    """
    Takes in txt file with (omega_m,n_s,A_s,E_ds,f_phi) for all k
    For a certain backend file number (a certain k) it creates a lua file that makes HiCOLA output in a separate folder
    """

    wb = 0.02196
    wr = 4.28e-5
    #sample = Omega_m , n_s    , A_s ,h,  f_phi, EdS, k_1dS, g_31dS, k_2dS, g_32dS
    n_s = sample[1]
    A_s = sample[2]
    h = sample[3]
    wm = sample[0]*h**2

    f_phi = sample[4]
    
    # Derived params
    Omg_r = wr/h**2
    Omg_m = wm/h**2
    Omg_b = wb/h**2
    Omg_Lambda = (1-f_phi)*(1-Omg_m-Omg_r)
    Omg_DE = (1-Omg_m-Omg_r)
    
    a= open('/home/c2042999/HiCOLA_env/Cubic_galileon_emu-ICGweek/Hi-COLA_params_emu.lua','r')
    b = a.readlines()
    c = open('/home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_GR_phasepair_{}.lua'.format(str(k)),'w')
    for i in range(len(b)):
        if i==19:
            c.write('simulation_name = "my_new_Hi-COLA_simulation_GR_phasepair_{}"'.format(str(k))+'\n')
        elif i==21:
            c.write('simulation_boxsize = '+str(boxsize)+'\n')
        elif i==38:
            c.write('cosmology_model = "LCDM"'+'\n')
        elif i== 40:
            c.write('cosmology_OmegaCDM = '+str((wm-wb)/h**2)+'\n')
        elif i== 42:
            c.write('cosmology_Omegab = '+str(wb/h**2)+'\n')
        elif i== 46:
            c.write('cosmology_OmegaLambda = '+str(Omg_DE)+'\n')
        elif i== 50:
            c.write('cosmology_TCMB_kelvin = '+str(T_CMB)+'\n')
        elif i== 52:
            c.write('cosmology_h = '+str(h)+'\n')
        elif i== 54:
            c.write('cosmology_As = '+str(A_s)+'\n')
        elif i== 56:
            c.write('cosmology_ns = '+str(n_s)+'\n')
        elif i== 63:
            c.write('  HiCOLA_expansion_filename = "None"'+'\n')
        elif i== 95:
            c.write('gravity_model = "GR"'+'\n')
        elif i== 100:
            c.write('  HiCOLA_preforce_filename = "None"'+'\n')
        elif i== 208:
            c.write('particle_Npart_1D = '+str(n_particles)+'\n')
        elif i== 210:
            c.write('particle_allocation_factor = '+str(2.0)+'\n')
        elif i== 222:
            c.write('output_folder = "/home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_{}"'.format(str(k))+'\n')
        elif i== 229:
            c.write('timestep_nsteps = {50}'+'\n')  
        elif i== 247:
            c.write('ic_random_seed ='+str(108)+'\n')
        elif i== 251:
            c.write('ic_fix_amplitude = true'+'\n')
        elif i== 253:
            c.write('ic_reverse_phases = true'+'\n') 
        elif i== 269:
            c.write('ic_input_filename = "/home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat"'+'\n')
        elif i== 271:
            c.write('ic_input_redshift = 49.0'+'\n')
        elif i== 312:
            c.write('force_nmesh = '+str(n_mesh)+'\n')
        elif i== 345:
            c.write('pofk_nmesh = '+str(n_mesh)+'\n')
        #elif i== 359:
        #    c.write('pofk_multipole_nmesh = '+str(n_mesh)+'\n')
        #elif i== 375:
        #    c.write('bispectrum_nmesh = '+str(n_mesh)+'\n')
        else:
            c.write(b[i])

    c.close()
    a.close()

# %%
## Create GR lua files

rewriteluafile_GR(8,sample_new,400,512,1536)
# phase pair
rewriteluafile_GR_phasepair(8,sample_new,400,512,1536)

# %%
"""Create P(k) GR"""

os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_GR_8.lua")
# Out:
# #=====================================================
# #           ________________  .____
# #           \_   _____/     \ |    |
# #            |    __)/  \ /  \|    |
# #            |     \/    Y    \    |___
# #            \___  /\____|__  /_______ \
# #                \/         \/        \/
# #
# # Initializing FML, MPI and FFTW
# # MPI is enabled. Running with 32 MPI tasks
# # OpenMP is enabled. Main task has 40 threads availiable
# # MPI + Threads is working
# # FFTW is enabled. Thread support is enabled
# #
# # List of tasks:
# # Task    0 [pulsar-cn-3]
# #     x-domain [       0 ,  0.03125)
# # Task    1 [pulsar-cn-3]
# #     x-domain [ 0.03125 ,   0.0625)
# # Task    2 [pulsar-cn-3]
# #     x-domain [  0.0625 ,  0.09375)
# # Task    3 [pulsar-cn-3]
# #     x-domain [ 0.09375 ,    0.125)
# # Task    4 [pulsar-cn-3]
# #     x-domain [   0.125 ,  0.15625)
# # Task    5 [pulsar-cn-3]
# #     x-domain [ 0.15625 ,   0.1875)
# # Task    6 [pulsar-cn-3]
# #     x-domain [  0.1875 ,  0.21875)
# # Task    7 [pulsar-cn-3]
# #     x-domain [ 0.21875 ,     0.25)
# # Task    8 [pulsar-cn-3]
# #     x-domain [    0.25 ,  0.28125)
# # Task    9 [pulsar-cn-3]
# #     x-domain [ 0.28125 ,   0.3125)
# # Task   10 [pulsar-cn-3]
# #     x-domain [  0.3125 ,  0.34375)
# # Task   11 [pulsar-cn-3]
# #     x-domain [ 0.34375 ,    0.375)
# # Task   12 [pulsar-cn-3]
# #     x-domain [   0.375 ,  0.40625)
# # Task   13 [pulsar-cn-3]
# #     x-domain [ 0.40625 ,   0.4375)
# # Task   14 [pulsar-cn-3]
# #     x-domain [  0.4375 ,  0.46875)
# # Task   15 [pulsar-cn-3]
# #     x-domain [ 0.46875 ,      0.5)
# # Task   16 [pulsar-cn-3]
# #     x-domain [     0.5 ,  0.53125)
# # Task   17 [pulsar-cn-3]
# #     x-domain [ 0.53125 ,   0.5625)
# # Task   18 [pulsar-cn-3]
# #     x-domain [  0.5625 ,  0.59375)
# # Task   19 [pulsar-cn-3]
# #     x-domain [ 0.59375 ,    0.625)
# # Task   20 [pulsar-cn-3]
# #     x-domain [   0.625 ,  0.65625)
# # Task   21 [pulsar-cn-3]
# #     x-domain [ 0.65625 ,   0.6875)
# # Task   22 [pulsar-cn-3]
# #     x-domain [  0.6875 ,  0.71875)
# # Task   23 [pulsar-cn-3]
# #     x-domain [ 0.71875 ,     0.75)
# # Task   24 [pulsar-cn-3]
# #     x-domain [    0.75 ,  0.78125)
# # Task   25 [pulsar-cn-3]
# #     x-domain [ 0.78125 ,   0.8125)
# # Task   26 [pulsar-cn-3]
# #     x-domain [  0.8125 ,  0.84375)
# # Task   27 [pulsar-cn-3]
# #     x-domain [ 0.84375 ,    0.875)
# # Task   28 [pulsar-cn-3]
# #     x-domain [   0.875 ,  0.90625)
# # Task   29 [pulsar-cn-3]
# #     x-domain [ 0.90625 ,   0.9375)
# # Task   30 [pulsar-cn-3]
# #     x-domain [  0.9375 ,  0.96875)
# # Task   31 [pulsar-cn-3]
# #     x-domain [ 0.96875 ,        1)
# #
# #=====================================================
#
#
# #=====================================================
# #
# #            .___        _____
# #            |   | _____/ ____\____
# #            |   |/    \   __\/  _ \
# #            |   |   |  \  | (  <_> )
# #            |___|___|  /__|  \____/
# #                     \/
# #
# # Information about (an empty) particle of the given type:
# # Below we only show info about methods we have implemented support for
# # Particle uses fiducial communication append_to_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial communication assign_from_buffer method (assumes no dynamic alloc inside class)
# # Particle uses fiducial size method. Size of particle is 104 bytes
# # Dimension is 3
# # Particle has [Position] (24 bytes)
# # Particle has [Velocity] (24 bytes)
# # Particle has [ID] (8 bytes)
# # Particle has [1LPT Displacement field] (12 bytes)
# # Particle has [2LPT Displacement field] (12 bytes)
# # Particle has [Lagrangian position] (24 bytes)
# # Particle compatible with 2LPT COLA
# # Particle compatible with 2+ LPT scaledependent COLA
# #
# #=====================================================
#
#
# #=====================================================
# # Parameter map contains 55 elements:
# #=====================================================
#   all_parameters_must_be_in_file : true
#   bispectrum                     : false
#   cosmology_As                   : 2.092e-09
#   cosmology_Neffective           : 3.046
#   cosmology_OmegaCDM             : 0.238611
#   cosmology_OmegaLambda          : 0.720179
#   cosmology_OmegaMNu             : 0
#   cosmology_Omegab               : 0.0411296
#   cosmology_TCMB_kelvin          : 2.72548
#   cosmology_h                    : 0.7307
#   cosmology_kpivot_mpc           : 0.05
#   cosmology_model                : LCDM
#   cosmology_ns                   : 0.9626
#   fof                            : false
#   force_density_assignment_method : CIC
#   force_kernel                   : continuous_greens_function
#   force_linear_massive_neutrinos : true
#   force_nmesh                    : 1536
#   gravity_model                  : GR
#   ic_LPT_order                   : 2
#   ic_fix_amplitude               : true
#   ic_initial_redshift            : 49
#   ic_input_filename              : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
#   ic_input_redshift              : 49
#   ic_nmesh                       : 512
#   ic_random_field_type           : gaussian
#   ic_random_generator            : GSL
#   ic_random_seed                 : 108
#   ic_reverse_phases              : false
#   ic_sigma8                      : 0.83
#   ic_sigma8_normalization        : false
#   ic_sigma8_redshift             : 0
#   ic_type_of_input               : powerspectrum
#   ic_use_gravity_model_GR        : true
#   output_fileformat              : GADGET
#   output_folder                  : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_8
#   output_particles               : false
#   output_redshifts               : [              0 ]
#   particle_Npart_1D              : 512
#   particle_allocation_factor     : 2
#   pofk                           : true
#   pofk_density_assignment_method : PCS
#   pofk_interlacing               : true
#   pofk_multipole                 : false
#   pofk_nmesh                     : 1536
#   pofk_subtract_shotnoise        : true
#   simulation_boxsize             : 400
#   simulation_name                : my_new_Hi-COLA_simulation_GR_8
#   simulation_use_cola            : true
#   simulation_use_scaledependent_cola : true
#   timestep_algorithm             : KDK
#   timestep_cola_nLPT             : -2.5
#   timestep_method                : Quinn
#   timestep_nsteps                : [              50 ]
#   timestep_scalefactor_spacing   : linear
# #=====================================================
#
#
# #=====================================================
# # Cosmology [LCDM]
# # Omegab      : 0.0411296
# # OmegaM      : 0.279741
# # OmegaMNu    : 0
# # OmegaCDM    : 0.238611
# # OmegaLambda : 0.720177
# # OmegaR      : 4.63157e-05
# # OmegaNu     : 3.20398e-05
# # OmegaRtot   : 7.83555e-05
# # OmegaK      : 0
# # h           : 0.7307
# # N_nu        : 3
# # Neff        : 3.046
# # Mnu         : 0 eV
# # TCMB        : 2.72548 K
# # Tnu         : 1.95277 K
# # As          : 2.092e-09
# # ns          : 0.9626
# # kpivot      : 0.05 1/Mpc
# #=====================================================
#
# #=====================================================
# # GravityModel is [GR] and has the cosmology: [LCDM]
# # Growth factors unity at zini = 49
# # Starting integrating growth factors from z = 499
# # scaledependent_growth : false
# #=====================================================
#
#
# #=====================================================
# # NBodySimulation::read_parameters
# #=====================================================
#
# simulation_name                          : my_new_Hi-COLA_simulation_GR_8
# simulation_boxsize                       : 400
# simulation_use_cola                      : true
# simulation_use_scaledependent_cola       : true
# force_nmesh                              : 1536
# force_kernel                             : continuous_greens_function
# force_density_assignment_method          : CIC
# force_linear_massive_neutrinos           : true
# ic_type_of_input                         : powerspectrum
# ic_input_filename                        : /home/c2042999/PCA_project/HiCOLA_files/P_k_z.dat
# ic_random_field_type                     : gaussian
# ic_input_redshift                        : 49
# ic_nmesh                                 : 512
# ic_random_seed                           : 108
# ic_random_generator                      : GSL
# ic_LPT_order                             : 2
# ic_fix_amplitude                         : true
# ic_reverse_phases                        : false
# ic_type_of_input                         : powerspectrum
# particle_Npart_1D                        : 512
# particle_allocation_factor               : 2
# timestep_nsteps                          : 50
# timestep_method                          : Quinn
# timestep_algorithm                       : KDK
# timestep_scalefactor_spacing             : linear
# pofk                                     : true
# pofk_nmesh                               : 1536
# pofk_interlacing                         : true
# pofk_subtract_shotnoise                  : true
# pofk_density_assignment_method           : PCS
# output_particles                         : false
# output_redshifts                         : 0 ,
# output_fileformat                        : GADGET
# output_folder                            : /home/c2042999/PCA_project/HiCOLA_files/Output_backend/COLA_GR_8
#
# #=====================================================
# # Create initial conditions
# #=====================================================

# %%
"""Create P(k) phasepair GR"""

os.system("cd; cd /home/c2042999/HiCOLA_env/Hi-COLA/HiCOLA/FML/COLASolver; mpirun -np 32 nbody /home/c2042999/PCA_project/HiCOLA_files/Hi-COLA_params_GR_phasepair_8.lua")
